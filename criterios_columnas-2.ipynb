# %% [markdown]
# 2. string a float (Elena)
# age
# totalworkinghours
# workinglifebalance
# daily rate (comas por puntos y quitarle el símbolo del dolar)
# hourly rate
# monthlyincome
# monthlyrate
# 3. int a float(Ana)
# distance from home
# 4. Numéricas a string(Ana)
# gender - cambiarlo a string: male =0; female=1
# 4b. Correctiones(Johana)
# distance from home - de negativos a positivos
# 5. Cambiar A Yes/No
# attrition (HECHA)
# overtime (HECHA).Pendiente del punto10
# remotework(HECHA)
# 6. homogeneizar categóricas HECHO
# educationfield (minúsculas)
# jobrole (minúsculas)
# maritalstatus(minúsculas y homogeneización)
#
# 7. Correspondencia de valor --- VERIFICACIÓN DE ESTA CLASIFICACIÓN ELENA
# education (1 menos y 5 más educación) -  a priori - verlo con todas las columnas
# jobinvolvement (1 menos y 4 máximo) -  a priori
# joblevel (1 mínimo y 5 máximo) - a priori
# jobsatisfaction (1 mínimo y 4 máximo) - a priori
# relationshiptsatisfaction (1 mínimo y 4 máximo) - a priori
# stockoption (0 sin opciones y 1-3 de pocas acciones a muchas) - a priori
# workinglifebalance (1 mínimo -4 máximo) -a prioru
#
# 8. Correspondencia ya determinada en apuntes BELEN
# environmental satisfaction (1 menos satisfecho y 4 muy satisfecho)
# Crear columna
#
# 9. Crear columnas descriptivas BELEN
# descriptivo de job_involvement
# jobsatisfaction
# relationshipsatisfaction
# stockoptionlevel - crear una con Fase=0 y True!=0
# workinglifebalance
#
# 10. Nulos ANA(CATEGORICOS Y ELENA(NUMERICOS)) OBSERVACION PREVIA Y ALGO DE CODIGO Y SE CONSENSUARA EL MARTES
# businesstravel
# department - muchos nulos
# hourly_rate = 84 nulos
# education field
# Environmental satisfaction -- poner a nulos los 100 errores
# marital status - 119
# monthlyincome
# overtime
# performancerating - 195 nulos
# workinglifebalance - 108
# Role in department - muchos nulos
#
# 11. Role in department ANA
# Dividir y normalizar campos y verificar si es lo mismo q job-role y department - posibilemente borrar
# 12. borrar
# employeecount
# over18
# performancerating - ponerla en relación con otras columnas para entenderla mejor
# standardhours - no comprendemos la columna y muchos nulos
# years in current role - muchísimos nulos
# sameasmontlyincome - copia de columna "monthly income"
# salary - sólo un valor para todos
# numberofchildren - no hay valores
# 13. Recomendaciones (a priori)
# - Datos sobre hijos -  i.e tomar medidas para retener a empleados (guardería)
