# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/elenag/anaconda3/lib/python3.9/site-packages (0.24.2)
# Requirement already satisfied: scipy>=0.19.1 in /home/elenag/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.7.1)
# Requirement already satisfied: joblib>=0.11 in /home/elenag/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /home/elenag/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.20.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/elenag/anaconda3/lib/python3.9/site-packages (from scikit-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install mysql-connector-python
# !pip install mysql-connector
# Out:
# Requirement already satisfied: mysql-connector-python in /home/elenag/anaconda3/lib/python3.9/site-packages (8.2.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in /home/elenag/anaconda3/lib/python3.9/site-packages (from mysql-connector-python) (4.21.12)
# Requirement already satisfied: mysql-connector in /home/elenag/anaconda3/lib/python3.9/site-packages (2.2.9)

# %%
# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd
from pandas import DataFrame
import numpy as np
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Librerías de visualización
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

# establece el estilo del fondo de las gráficas como "whitegrid". Las gráficas tendrán un fondo blanco con líneas de cuadrícula horizontales y verticales.
sns.set_style("whitegrid")

# cambiará el esquema de colores predeterminado de Seaborn a uno más oscuro, adecuado para gráficas con fondos claros. 
sns.set_theme(style="dark")

# establece el estilo en Solarize_Lihgt2. 
plt.style.use('Solarize_Light2')

# Evaluar linealidad de las relaciones entre las variables
# ------------------------------------------------------------------------------
from scipy.stats import shapiro, kstest

import scipy.stats as stats

# -----------------------------------------------------------------------
from scipy.stats import chi2_contingency
from scipy.stats import ttest_ind
from scipy.stats import mannwhitneyu
from scipy.stats import levene

# import mysql.connector
# from mysql.connector import errorcode
# import pymysql

# %%
df_data_original =pd.read_csv("DATA.CSV",index_col=0)
df_data_original.head(2).T
# Out:
#                                             0              1
# Age                                        51             52
# Attrition                                  No             No
# BusinessTravel                            NaN            NaN
# DailyRate                              684,0$         699,0$
# Department                                NaN            NaN
# DistanceFromHome                            6              1
# Education                                   3              4
# EducationField                            NaN  Life Sciences
# employeecount                               1              1
# employeenumber                          162,0          259,0
# EnvironmentSatisfaction                     1              3
# Gender                                      0              0
# HourlyRate                                 51             65
# JobInvolvement                              3              2
# JobLevel                                    5              5
# JobRole                    resEArch DIREcToR        ManAGeR
# JobSatisfaction                             3              3
# MaritalStatus                             NaN            NaN
# MonthlyIncome                         19537,0        19999,0
# MonthlyRate                              6462           5678
# NUMCOMPANIESWORKED                          7              0
# Over18                                      Y            NaN
# OverTime                                   No            NaN
# PercentSalaryHike                          13             14
# PerformanceRating                         3,0            3,0
# RelationshipSatisfaction                    3              1
# StandardHours                             NaN            NaN
# StockOptionLevel                            0              1
# TOTALWORKINGYEARS                         NaN           34,0
# TrainingTimesLastYear                       5              5
# WORKLIFEBALANCE                           3,0            3,0
# YearsAtCompany                             20             33
# YearsInCurrentRole                        NaN            NaN
# YearsSinceLastPromotion                    15             11
# YEARSWITHCURRMANAGER                       15              9
# SameAsMonthlyIncome                   19537,0        19999,0
# DateBirth                                1972           1971
# Salary                            1000000000$    1000000000$
# RoleDepartament                           NaN            NaN
# NUMBERCHILDREN                            NaN            NaN
# RemoteWork                                Yes              1

# %%
df_data_copy= df_data_original.copy()

# %%
df_data_copy.head(2)
# Out:
#   Age Attrition BusinessTravel DailyRate Department  DistanceFromHome  \
# 0  51        No            NaN    684,0$        NaN                 6
# 1  52        No            NaN    699,0$        NaN                 1
#
#    Education EducationField  employeecount employeenumber  \
# 0          3            NaN              1          162,0
# 1          4  Life Sciences              1          259,0
#
#    EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  JobLevel  \
# 0                        1       0         51               3         5
# 1                        3       0         65               2         5
#
#                JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# 0   resEArch DIREcToR                 3           NaN       19537,0
# 1             ManAGeR                 3           NaN       19999,0
#
#    MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# 0         6462                   7      Y       No                 13
# 1         5678                   0    NaN      NaN                 14
#
#   PerformanceRating  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0               3,0                         3           NaN                 0
# 1               3,0                         1           NaN                 1
#
#   TOTALWORKINGYEARS  TrainingTimesLastYear WORKLIFEBALANCE  YearsAtCompany  \
# 0               NaN                      5             3,0              20
# 1              34,0                      5             3,0              33
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YEARSWITHCURRMANAGER  \
# 0                NaN                       15                    15
# 1                NaN                       11                     9
#
#   SameAsMonthlyIncome  DateBirth       Salary RoleDepartament  NUMBERCHILDREN  \
# 0             19537,0       1972  1000000000$             NaN             NaN
# 1             19999,0       1971  1000000000$             NaN             NaN
#
#   RemoteWork
# 0        Yes
# 1          1

# %% [markdown]
# # FASE 1.ANÁLISIS EXPLORATORIO (EDA)

# %%
# Análisis realizado en archivo "fase1_eda.ipynb"

# %% [markdown]
# # FASE 2. TRANSFORMACIÓN DE DATOS
# - 2.0 Homogeneización nombre columnas
# - 2.1 Modificar columnas categóricas a numéricas
# - 2.2 Homogeneizar las etiquetas de las columnas categóricas
# - 2.3 Modificar valores erróneos a nulos
# - 2.4 Creación de nuevas columnas
# - 2.5 Duplicados
# - 2.6 Duplicados employee_number
# - 2.7 Nulos
# - 2.8 Eliminar columnas
# - 2.9 Verificación de categorías
# - 2.10 generación de csv "definitivo" tras limpieza de datos

# %% [markdown]
# #### 2.0 Homogeneización nombre columnas

# %%
nuevas_columnas={columna:columna.lower() for columna in df_data_copy} #modificamos las columnas a minúsculas
df_data_copy.rename(columns= nuevas_columnas, inplace= True) #cambiamos las columnas antiguas por las homogeneizadas en el paso anterior (nuevas_columnas)

# %%
df_data_copy.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'gender', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobrole', 'jobsatisfaction',
#        'maritalstatus', 'monthlyincome', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'sameasmonthlyincome', 'datebirth', 'salary',
#        'roledepartament', 'numberchildren', 'remotework'],
#       dtype='object')

# %% [markdown]
# #### 2.1 Cambiar de strings (objeto) a numéricas

# %%
#____STRING A INT_________
#age:               12 valores en letras: cambiarlos a nros + convertir todos los nros a int.
#worklifebalance quitar ",0" y convertir a int.

#____STRING A FLOAT_________
#totalworkingyears: cambiar comas por puntos
#daily rate (comas por puntos y quitarle el símbolo del dolar)
#hourly rate
#monthlyincome
#monthlyrate

# %%
#Age:
def texto_nro(cadena):
    cadena = cadena.replace("twenty-six","26").replace("twenty-four","24").replace("thirty-two","32").replace("thirty-six","36").replace("thirty-seven","37").replace("thirty-one","31").replace("thirty","30").replace("forty-seven","47").replace("fifty-two","52").replace("fifty-five","55").replace("fifty-eight","58")
    return int(cadena)

df_data_copy["age"] = df_data_copy["age"].apply(texto_nro)

# %%
#employeenumber

# %%
df_data_copy["employeenumber"].isnull().sum()
# Out:
# 431

# %%
df_data_copy["employeenumber"]
# Out:
# 0       162,0
# 1       259,0
# 2       319,0
# 3         NaN
# 4         NaN
#         ...
# 1609    967,0
# 1610    972,0
# 1611      NaN
# 1612    990,0
# 1613      NaN
# Name: employeenumber, Length: 1614, dtype: object

# %%
#Worklifebalance y employeenumber

def nro(cadena):

    try: 
        cadena = cadena.replace(",0","")
        return float(cadena)
    
    except: 
        return np.nan #tiene varios valores que son "nan"

df_data_copy["worklifebalance"] = df_data_copy["worklifebalance"].apply(nro)

# %%
df_data_copy["employeenumber"] = df_data_copy["employeenumber"].apply(nro)

# %%
#dailyrate 
def daily(nro):
    try:
        return float(nro.replace(",0$",""))
    except:
        return np.nan

df_data_copy["dailyrate"] = df_data_copy["dailyrate"].apply(daily)

# %%
# totalworkingyears", "monthlyincome", "monthlyrate: Cambio de string a float

def decimal(cadena):

    try: 
        return float(cadena.replace(",",".").replace("$","."))

    except: 
        return np.nan #tiene varios valores que son "nan"
    
columnas_decimal = ["totalworkingyears", "monthlyincome"]

for columna in columnas_decimal:
    df_data_copy[columna] = df_data_copy[columna].apply(decimal)

# %%
# "hourlyrate", "monthlyrate" : cambio de string a float - no tienen decimales

def decimal3(cadena):
    try:
        return float(cadena)
    except:
        return np.nan

col_dec_ent = ["hourlyrate", "monthlyrate"]

for columna in col_dec_ent:
    df_data_copy[columna] = df_data_copy[columna].apply(decimal3)

# %%
## Nota: hourlyrate - parecía en el original como si no hubiese nulos pero había algunos que eran "Not available" y q contaban como interger

# %% [markdown]
# #### 2.2 Homogeneizar categóricas

# %%
#Columnas a homogeneizar sus categorías:
# educationfield (minúsculas)
# jobrole (minúsculas)
# maritalstatus(minúsculas y homogeneización)

def homogeneizar(cadena):
    try:
        return cadena.lower().replace("marreid","married")
    except:
        return np.nan

col_homo = ["educationfield", "jobrole", "maritalstatus"]

for columna in col_homo:
    df_data_copy[columna] = df_data_copy[columna].apply(homogeneizar)

# %%
# Homogeneizar "remotework" a 2 opciones: Yes, No
df_data_copy["remotework"] = df_data_copy["remotework"].replace({"True": "Yes", 'False': "No", '0': "No", '1': "Yes"})

# %%
len(df_data_copy[df_data_copy["distancefromhome"]<0])
# Out:
# 192

# %% [markdown]
# #### 2.3 Modificar valores erróneos a nulos

# %%
#Distancefromhome - Valores negativos (192 valores) a nulos
def convertir_nulos(numero):
    if numero < 0:
        return np.nan
    else:
        return numero

df_data_copy["distancefromhome"] = df_data_copy["distancefromhome"].apply(convertir_nulos)

# %%
#Environmentalsatisfaction: modificar valores diferentes a 1-4 a nulos
def convertir_nulos (numero):
    if numero == 1:
        return numero
    elif numero == 2: 
        return numero
    elif numero == 3:
        return numero
    elif numero == 4:
        return numero
    else:
        return np.nan

#Creación de una columna con la función
df_data_copy["environmentsatisfaction"] = df_data_copy["environmentsatisfaction"].apply(convertir_nulos)

# %% [markdown]
# #### 2.4 Creación de nuevas columnas

# %%
#1. GÉNERO

#Creamos la función 
def categorizar_gender (numero):
    if numero == 0:
        return 'male'
    else:
        return 'female'

# %%
#Creación de una columna con la función
df_data_copy.insert(12, 'gender_cat', df_data_copy["gender"].apply(categorizar_gender))

# %%
#2. environmentsatisfaction,relationshipsatisfaction,worklifebalance

def categorizar_environmentsatisfaction(valor):

    if valor == 4:
        return "maximun"
    elif valor == 3:
        return "medium"
    elif valor == 2:
        return "little"
    elif valor == 1:
        return "nothing"
    else:
        return "unknown"

#df_data_copy["environmentsatisfaction_cat"] = df_data_copy["environmentsatisfaction"].apply(categorizar_environmentsatisfaction)
#df_data_copy["relationshipsatisfaction_cat"] = df_data_copy["relationshipsatisfaction"].apply(categorizar_environmentsatisfaction)
#df_data_copy["worklifebalance_cat"] = df_data_copy["worklifebalance"].apply(categorizar_environmentsatisfaction)

# %%
df_data_copy.insert(11, 'environmentsatisfaction_cat', df_data_copy["environmentsatisfaction"].apply(categorizar_environmentsatisfaction))

# %%
df_data_copy.insert(28, 'relationshipsatisfaction_cat', df_data_copy["relationshipsatisfaction"].apply(categorizar_environmentsatisfaction))

# %%
df_data_copy.insert(34, 'worklifebalance_cat', df_data_copy["worklifebalance"].apply(categorizar_environmentsatisfaction))

# %%
#education
def categorizar_education(valor):
    if valor == 5:
        return "university"
    elif valor == 3:
        return "college"
    elif valor == 2:
        return "high school"
    elif valor == 1:
        return "middle school"
    else:
        return "Unknown"

# %%
df_data_copy.insert(7, 'education_cat', df_data_copy["education"].apply(categorizar_education))

# %%
#"jobinvolvement"

def categorizar_jobinvolvement(valor):
    if valor == 4:
        return "very involved"
    elif valor == 3:
        return "involved"
    elif valor == 2:
        return "little involved"
    elif valor == 1:
        return "not involved"
    else:
        return "Unknown"

# %%
df_data_copy.insert(17, 'jobinvolvement_cat', df_data_copy["jobinvolvement"].apply(categorizar_jobinvolvement))

# %%
mapa = {"No":0, "Yes":1}

df_data_copy["attrition_number"] = df_data_copy["attrition"].map(mapa)

# %%
df_data_copy["attrition_number"].value_counts()
# Out:
# 0    1355
# 1     259
# Name: attrition_number, dtype: int64

# %% [markdown]
# #### 2.5 Duplicados (filas)

# %%
#Nro. de duplicados (todas las filas son iguales)
df_data_copy.duplicated().sum()
# Out:
# 43

# %%
#eliminar duplicados
df_data_copy = df_data_copy.drop_duplicates()
print("Cantidad de filas después de eliminar duplicados:", len(df_data_copy))
# Out:
# Cantidad de filas después de eliminar duplicados: 1571

# %% [markdown]
# #### 2.6 Duplicados (employeenumber)
# -- Tenemos varios empleados repetidos, borramos el primero (keep=last --> qre decir que mantenemos el primero), ya que asumimos que los primeros registros insertados son más antiguos que los últimos

# %%
df_data_copy["employeenumber"].duplicated().sum()
# Out:
# 491

# %%
df_data_copy.drop_duplicates(subset="employeenumber",keep="last",inplace=True)

# %%
df_data_copy.shape
# Out:
# (1080, 48)

# %% [markdown]
# #### 2.7 Nulos

# %%
#1.CATEGÓRICAS - Ana
# businesstravel
# department - muchos nulos
# education field
# marital status - 119
# overtime
# performancerating - 195 nulos
# Role in department - muchos nulos

# %%
#Lsta de columnas categoricas con nulos
nulos_esta_cat = df_data_copy[df_data_copy.columns[df_data_copy.isnull().any()]].select_dtypes(include = "O").columns
print("Las columnas categóricas que tienen nulos son : \n ")
print(nulos_esta_cat)
# Out:
# Las columnas categóricas que tienen nulos son :
#
# Index(['businesstravel', 'department', 'educationfield', 'maritalstatus',
#        'over18', 'overtime', 'performancerating', 'standardhours',
#        'yearsincurrentrole', 'sameasmonthlyincome', 'roledepartament'],
#       dtype='object')

# %%
df_data_copy.isnull().sum()
# Out:
# age                                0
# attrition                          0
# businesstravel                   535
# dailyrate                         85
# department                       873
# distancefromhome                 125
# education                          0
# education_cat                      0
# educationfield                   496
# employeecount                      0
# employeenumber                     1
# environmentsatisfaction           66
# environmentsatisfaction_cat        0
# gender                             0
# gender_cat                         0
# hourlyrate                        62
# jobinvolvement                     0
# jobinvolvement_cat                 0
# joblevel                           0
# jobrole                            0
# jobsatisfaction                    0
# maritalstatus                    426
# monthlyincome                    560
# monthlyrate                        0
# numcompaniesworked                 0
# over18                           606
# overtime                         447
# percentsalaryhike                  0
# performancerating                137
# relationshipsatisfaction           0
# relationshipsatisfaction_cat       0
# standardhours                    799
# stockoptionlevel                   0
# totalworkingyears                360
# trainingtimeslastyear              0
# worklifebalance                   68
# worklifebalance_cat                0
# yearsatcompany                     0
# yearsincurrentrole              1057
# yearssincelastpromotion            0
# yearswithcurrmanager               0
# sameasmonthlyincome              560
# datebirth                          0
# salary                             0
# roledepartament                  873
# numberchildren                  1080
# remotework                         0
# attrition_number                   0
# dtype: int64

# %%
# El 'value_counts()' de cada una de las columnas categóricas que tienen nulos para saber como es la distribución de sus categorías
for col in nulos_esta_cat:
    print(f"La distribución de las categorías para la columna {col.upper()}")
    display(df_data_copy[col].value_counts() / df_data_copy.shape[0])
    print("........................")
# Out:
# La distribución de las categorías para la columna BUSINESSTRAVEL
# travel_rarely        0.347222
# travel_frequently    0.101852
# non-travel           0.055556
# Name: businesstravel, dtype: float64
# ........................
# La distribución de las categorías para la columna DEPARTMENT
#  Research & Development     0.127778
#  Sales                      0.056481
#  Human Resources            0.007407
# Name: department, dtype: float64
# ........................
# La distribución de las categorías para la columna EDUCATIONFIELD
# life sciences       0.220370
# medical             0.163889
# marketing           0.071296
# technical degree    0.044444
# other               0.035185
# human resources     0.005556
# Name: educationfield, dtype: float64
# ........................
# La distribución de las categorías para la columna MARITALSTATUS
# married     0.266667
# single      0.216667
# divorced    0.122222
# Name: maritalstatus, dtype: float64
# ........................
# La distribución de las categorías para la columna OVER18
# Y    0.438889
# Name: over18, dtype: float64
# ........................
# La distribución de las categorías para la columna OVERTIME
# No     0.415741
# Yes    0.170370
# Name: overtime, dtype: float64
# ........................
# La distribución de las categorías para la columna PERFORMANCERATING
# 3,0    0.739815
# 4,0    0.133333
# Name: performancerating, dtype: float64
# ........................
# La distribución de las categorías para la columna STANDARDHOURS
# 80,0    0.260185
# Name: standardhours, dtype: float64
# ........................
# La distribución de las categorías para la columna YEARSINCURRENTROLE
# 2,0     0.006481
# 7,0     0.002778
# 0,0     0.002778
# 6,0     0.001852
# 4,0     0.001852
# 3,0     0.001852
# 1,0     0.001852
# 12,0    0.000926
# 11,0    0.000926
# Name: yearsincurrentrole, dtype: float64
# ........................
# La distribución de las categorías para la columna SAMEASMONTHLYINCOME
# 2258,0     0.001852
# 6162,0     0.001852
# 2377,0     0.001852
# 2587,0     0.001852
# 3420,0     0.001852
#              ...
# 3102,0     0.000926
# 6380,0     0.000926
# 6349,0     0.000926
# 6502,0     0.000926
# 10845,0    0.000926
# Name: sameasmonthlyincome, Length: 508, dtype: float64
# ........................
# La distribución de las categorías para la columna ROLEDEPARTAMENT
#  MaNAgeR  -  Sales                                        0.001852
#  ManaGER  -  Research & Development                       0.000926
#  hEalthCaRe reprEseNTaTiVe  -  Research & Development     0.000926
#  reseARCh SCieNTisT  -  Research & Development            0.000926
#  reSEarcH scIENtISt  -  Research & Development            0.000926
#                                                             ...
#  SaLes exECutIVe  -  Sales                                0.000926
#  manAGER  -  Sales                                        0.000926
#  LaBOrATORy teCHnIciaN  -  Research & Development         0.000926
#  SAlES ExecuTIVe  -  Sales                                0.000926
#  sAleS EXECUtIvE  -  Sales                                0.000926
# Name: roledepartament, Length: 206, dtype: float64
# ........................

# %% [markdown]
# Performance rating es la única que tendría posibilidades de cambiar a la moda, las otras tienen valores muy bajos y seria convenientes cmabiar por desconocido.

# %%
#columnas_moda = ['performancerating']
columnas_desconocido = ['businesstravel', 'department', 'educationfield','maritalstatus','overtime']

# %%
#Columna moda
# for columna in columnas_moda:
#     moda = df_data_copy[col].mode()[0]    
#     df_data_copy[columna] = df_data_copy[columna].fillna(moda)

# print("Después del reemplazo usando 'fillna' quedan los siguientes nulos")
# df_data_copy[columnas_moda].isnull().sum()

# %%
#columna desconocido
for columna in columnas_desconocido:
    df_data_copy[columna] = df_data_copy[columna].fillna("Unknown") 

print("Después del reemplazo usando 'fillna' quedan los siguientes nulos")
df_data_copy[columnas_desconocido].isnull().sum()
# Out:
# Después del reemplazo usando 'fillna' quedan los siguientes nulos
# businesstravel    0
# department        0
# educationfield    0
# maritalstatus     0
# overtime          0
# dtype: int64

# %%
#2.NUMÉRICAS - Elena
# hourly_rate = 84 nulos
# Environmental satisfaction 
# monthlyincome
# worklifebalance - 108
# totalworkingyears
# numberofchildren

# %%
#Columnas numéricas con nulos 
nulos_num = df_data_copy[df_data_copy.columns[df_data_copy.isnull().any()]].select_dtypes(include = np.number).columns
print(nulos_num)
# Out:
# Index(['dailyrate', 'distancefromhome', 'employeenumber',
#        'environmentsatisfaction', 'hourlyrate', 'monthlyincome',
#        'totalworkingyears', 'worklifebalance', 'numberchildren'],
#       dtype='object')

# %%
#% de nulos en las columnas numéricas con nulos
nl = (df_data_copy[nulos_num].isnull().sum() / df_data_copy.shape[0]) * 100
#nl.sort_values(ascending=False).reset_index()
nl.reset_index()
# Out:
#                      index           0
# 0                dailyrate    7.870370
# 1         distancefromhome   11.574074
# 2           employeenumber    0.092593
# 3  environmentsatisfaction    6.111111
# 4               hourlyrate    5.740741
# 5            monthlyincome   51.851852
# 6        totalworkingyears   33.333333
# 7          worklifebalance    6.296296
# 8           numberchildren  100.000000

# %%
#Valores atípicos
fig, axes = plt.subplots(nrows = 5, ncols = 2, figsize = (8,10)) 
axes = axes.flat

for indice, col in enumerate(nulos_num):
    sns.boxplot(x = col, data = df_data_copy, ax = axes[indice])
    plt.xlabel(col)  

plt.tight_layout()
fig.delaxes(axes[-1])
plt.show();

# %% [markdown]
# #### Decisiones: Nulos (numéricas)
# - Number of children: borrarla
# - Monthly income: borrarla. Tiene 52% de nulos
# - Todas las demás: utilizar el iterate y knn imputer - atípicos en totalworkingyears

# %%
#ITERATIVE IMPUTER

imputer_iterative = IterativeImputer(max_iter =20, random_state=42)
imputer_iterative_imputado = imputer_iterative.fit_transform(df_data_copy[['environmentsatisfaction', 'hourlyrate','totalworkingyears', 'worklifebalance']])
imputer_iterative_imputado
# Out:
# array([[ 1.        , 51.        , 11.2819727 ,  3.        ],
#        [ 3.        , 65.        , 34.        ,  3.        ],
#        [ 3.        , 58.        , 22.        ,  2.76050668],
#        ...,
#        [ 3.        , 93.        ,  8.        ,  4.        ],
#        [ 3.        , 57.        , 11.26978057,  2.        ],
#        [ 4.        , 75.        , 11.23244313,  3.        ]])

# %%
df_data_copy[['environmentsatisfaction_iterativo', 'hourlyrate_iterativo', 'totalworkingyears_iterativo', 'worklifebalance_iterativo']] = imputer_iterative_imputado

# %%
#KNN IMPUTER
imputer_knn = KNNImputer(n_neighbors=5)
imputer_knn_imputado = imputer_knn.fit_transform(df_data_copy[['environmentsatisfaction', 'hourlyrate', 'totalworkingyears', 'worklifebalance']])
imputer_knn_imputado
# Out:
# array([[ 1. , 51. ,  8. ,  3. ],
#        [ 3. , 65. , 34. ,  3. ],
#        [ 3. , 58. , 22. ,  3.4],
#        ...,
#        [ 3. , 93. ,  8. ,  4. ],
#        [ 3. , 57. ,  5.4,  2. ],
#        [ 4. , 75. , 11.6,  3. ]])

# %%
df_data_copy[['environmentsatisfaction_knn', 'hourlyrate_knn', 'totalworkingyears_knn', 'worklifebalance_knn']] = imputer_knn_imputado

# %%
#Comparamos las estadísticas generadas de por el iterative y el knn para decidir cuál coger (aquel cuya media y mediana sea más parecida a la original- En la columna con valores atípicos cogemos aquel cuya mediana sea más parecida a la original)
df_data_copy.describe()[['environmentsatisfaction', 'environmentsatisfaction_iterativo', 'environmentsatisfaction_knn', 'hourlyrate', 'hourlyrate_iterativo', 'hourlyrate_knn', 'totalworkingyears', 'totalworkingyears_iterativo', 'totalworkingyears_knn', 'worklifebalance', 'worklifebalance_iterativo', 'worklifebalance_knn']].T
# Out:
#                                     count       mean        std   min   25%  \
# environmentsatisfaction            1014.0   2.723866   1.098632   1.0   2.0
# environmentsatisfaction_iterativo  1080.0   2.723781   1.064690   1.0   2.0
# environmentsatisfaction_knn        1080.0   2.738148   1.073926   1.0   2.0
# hourlyrate                         1018.0  66.013752  20.340074  30.0  48.0
# hourlyrate_iterativo               1080.0  66.000678  19.749606  30.0  50.0
# hourlyrate_knn                     1080.0  65.997222  19.857465  30.0  49.0
# totalworkingyears                   720.0  11.250000   7.567499   0.0   6.0
# totalworkingyears_iterativo        1080.0  11.251012   6.177447   0.0   8.0
# totalworkingyears_knn              1080.0  10.804259   6.441342   0.0   6.6
# worklifebalance                    1012.0   2.766798   0.701111   1.0   2.0
# worklifebalance_iterativo          1080.0   2.766791   0.678662   1.0   2.0
# worklifebalance_knn                1080.0   2.770926   0.682854   1.0   2.0
#
#                                          50%        75%    max
# environmentsatisfaction             3.000000   4.000000    4.0
# environmentsatisfaction_iterativo   3.000000   4.000000    4.0
# environmentsatisfaction_knn         3.000000   4.000000    4.0
# hourlyrate                         66.000000  84.000000  100.0
# hourlyrate_iterativo               66.000000  83.000000  100.0
# hourlyrate_knn                     66.000000  83.000000  100.0
# totalworkingyears                  10.000000  15.000000   40.0
# totalworkingyears_iterativo        11.216703  11.319691   40.0
# totalworkingyears_knn              10.000000  13.000000   40.0
# worklifebalance                     3.000000   3.000000    4.0
# worklifebalance_iterativo           3.000000   3.000000    4.0
# worklifebalance_knn                 3.000000   3.000000    4.0

# %% [markdown]
# ### Cuál coger?
# - env.satif_iterativo
# - hourlyrate_iterativo
# - totalworkingyears_iterativo
# - worklifebalance_iterativo

# %%
#Quitamos las columnas originales y las de aquellos métodos q están más alejados de la media y medianas de las originales
df_data_copy.drop(['environmentsatisfaction', 'environmentsatisfaction_knn', 'hourlyrate', 'hourlyrate_knn', 'totalworkingyears', 'totalworkingyears_knn', 'worklifebalance', 'worklifebalance_knn'], axis = 1, inplace = True)

# %%
nuevas_columnas = {'age': 'age', 'attrition': 'attrition', 'businesstravel': 'businesstravel', 
                    'dailyrate': 'dailyrate', 'department': 'department', 
                    'distancefromhome': 'distancefromhome', 'education': 'education', 
                    'education_cat': 'education_cat', 'educationfield': 'educationfield', 
                    'employeecount': 'employeecount', 'employeenumber': 'employeenumber', 
                    'environmentsatisfaction_cat': 'environmentsatisfaction_cat', 'gender': 'gender', 
                    'gender_cat': 'gender_cat', 'jobinvolvement': 'jobinvolvement', 
                    'jobinvolvement_cat': 'jobinvolvement_cat', 'joblevel': 'joblevel', 
                    'jobrole': 'jobrole', 'jobsatisfaction': 'jobsatisfaction', 
                    'maritalstatus': 'maritalstatus', 'monthlyrate': 'monthlyrate', 
                    'numcompaniesworked': 'numcompaniesworked', 'over18': 'over18', 
                    'overtime': 'overtime', 'percentsalaryhike': 'percentsalaryhike', 
                    'performancerating': 'performancerating', 
                    'relationshipsatisfaction': 'relationshipsatisfaction', 
                    'relationshipsatisfaction_cat': 'relationshipsatisfaction_cat', 
                    'standardhours': 'standardhours', 'stockoptionlevel': 'stockoptionlevel', 
                    'trainingtimeslastyear': 'trainingtimeslastyear', 
                    'worklifebalance_cat': 'worklifebalance_cat', 'yearsatcompany': 'yearsatcompany', 
                    'yearsincurrentrole': 'yearsincurrentrole', 
                    'yearssincelastpromotion': 'yearssincelastpromotion', 
                    'yearswithcurrmanager': 'yearswithcurrmanager', 
                    'sameasmonthlyincome': 'sameasmonthlyincome', 
                    'datebirth': 'datebirth', 'salary': 'salary', 
                    'roledepartament': 'roledepartament', 'numberchildren': 'numberchildren', 
                    'remotework': 'remotework', 
                    'environmentsatisfaction_iterativo': 'environmentsatisfaction', 
                    'hourlyrate_iterativo': 'hourlyrate', 
                    'totalworkingyears_iterativo': 'totalworkingyears', 
                    'worklifebalance_iterativo': 'worklifebalance'}

# %%
df_data_copy.rename(columns = nuevas_columnas, inplace = True)

# %%
#NOTA: Para crear las columnas de iterativo y de knn automáticamente

#---------------ITERATIVE-----------------------------------
# palabras = ['environmentsatisfaction', 'hourlyrate', 'monthlyincome',
#        'totalworkingyears', 'worklifebalance', 'numberchildren']

# palabras_iterativas = [palabra + '_iterativo' for palabra in palabras]

# print(palabras_iterativas)

# #---------------KNN-----------------------------------

# palabras2 = ['environmentsatisfaction', 'hourlyrate', 'monthlyincome',
#        'totalworkingyears', 'worklifebalance', 'numberchildren']

# palabras_iterativas = [palabra + '_knn' for palabra in palabras2]

# print(palabras_iterativas)

# #---------------TODAS JUNTAS-----------------------------------

# pal = ['environmentsatisfaction', 'hourlyrate', 'monthlyincome',
#        'totalworkingyears', 'worklifebalance', 'numberchildren']

# pal2 = ['environmentsatisfaction_iterativo', 'hourlyrate_iterativo', 'monthlyincome_iterativo', 'totalworkingyears_iterativo', 'worklifebalance_iterativo', 'numberchildren_iterativo']


# pal3 = ['environmentsatisfaction_knn', 'hourlyrate_knn', 'monthlyincome_knn', 'totalworkingyears_knn', 'worklifebalance_knn', 'numberchildren_knn']


# lista_concatenada = [item for sublist in zip(pal, pal2, pal3) for item in sublist]

# print(lista_concatenada)

# %% [markdown]
# #### 2.8 Eliminar columnas

# %%
# -Numberofchildren
# - over18
# - datebirth - No aporta nada nuevo ya que tenemos una columna con la edad
# - salary - sólo un valor para todos
# - sameasmontlyincome - copia de columna "monthly income"
# - monthlyincome - muchos nulos 52%
# - standardhours
# - employeecount
# - roledepartment
# - performancerating
# - years in currentrole

# %%
columnas_drop = ["numberchildren", "over18","datebirth","salary","sameasmonthlyincome", "monthlyincome","standardhours","employeecount", "performancerating", "yearsincurrentrole", "roledepartament"]

# %%
df_data_copy.drop(columns = columnas_drop, axis=1, inplace=True)

# %%
df_data_copy.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'education_cat', 'educationfield',
#        'employeenumber', 'environmentsatisfaction_cat', 'gender', 'gender_cat',
#        'jobinvolvement', 'jobinvolvement_cat', 'joblevel', 'jobrole',
#        'jobsatisfaction', 'maritalstatus', 'monthlyrate', 'numcompaniesworked',
#        'overtime', 'percentsalaryhike', 'relationshipsatisfaction',
#        'relationshipsatisfaction_cat', 'stockoptionlevel',
#        'trainingtimeslastyear', 'worklifebalance_cat', 'yearsatcompany',
#        'yearssincelastpromotion', 'yearswithcurrmanager', 'remotework',
#        'attrition_number', 'environmentsatisfaction', 'hourlyrate',
#        'totalworkingyears', 'worklifebalance'],
#       dtype='object')

# %% [markdown]
# #### 2.9 Verificación de clasificaciones categóricas
# - education (1 menos y 5 más educación)
#     Parece que es así pero hay personas con un nivel "1" de educación que son directores y managers y tb 1 q tienenn altos "hourlyrates"
#
# - jobinvolvement (1 menos y 4 máximo) -  a priori
#     No puedo determinarlo, no parece q esté unico a jobsatisfaction
#
# - jobsatisfaction (1 mínimo y 4 máximo) - a priori
#     No puedo determinarlo, no parece q esté unico a jobsatisfaction
#
# - joblevel (1 mínimo y 5 máximo) - a priori
#     Sí, el 1 son técnicos el 5 son managers, directores
#
# - relationshiptsatisfaction (1 mínimo y 4 máximo) - a priori
#     No guarda una relación directa con otras columnas
#
# - stockoption (0 sin opciones y 1-3 de pocas acciones a muchas) - a priori
# No guarda una relación directa con otras columnas. Hay empleados q llevan 0 años trabjando y tienen el nivel 3 de opciones. y tampoco por el tipo de posición hay relación
#
# - workinglifebalance (1 mínimo -4 máximo) -a prioru
# tampoco existe relación directa con otras columnas

# %%
#relationshipsatisfaction

# %%
#df_data_copy[["education","educationfield","age","joblevel","jobrole", "hourlyrate","monthlyrate","yearsatcompany"]].sort_values(by = "hourlyrate", ascending=False).head(50)

# %%
#df_data_copy[["jobinvolvement","environmentsatisfaction","jobsatisfaction"]].sort_values(by = "jobinvolvement", ascending=False).tail(50)

# %%
#df_data_copy[["joblevel","jobrole", "hourlyrate","monthlyrate","yearsatcompany","education","educationfield","age"]].sort_values(by = "joblevel", ascending=False).head(50)

# %%
#df_data_copy[["jobinvolvement","environmentsatisfaction","jobsatisfaction"]].sort_values(by = "jobsatisfaction", ascending=False).tail(50)

# %%
#df_data_copy[["jobinvolvement","environmentsatisfaction","jobsatisfaction", "relationshipsatisfaction"]].sort_values(by = "relationshipsatisfaction", ascending=False).head(50)

# %%
#df_data_copy[["stockoptionlevel", "yearsatcompany","totalworkingyears","joblevel","jobrole"]].sort_values(by = "stockoptionlevel", ascending=False).head(50)

# %%
#df_data_copy[["worklifebalance","jobinvolvement","environmentsatisfaction","jobsatisfaction", "relationshipsatisfaction"]].sort_values(by = "worklifebalance", ascending=False).head(50)

# %% [markdown]
# 2.10. Generación de csv

# %%
df_data_copy.to_csv("definitivo.csv")

# %%
definitivo = pd.read_csv("definitivo.csv", index_col = 0)

# %%
definitivo.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'education_cat', 'educationfield',
#        'employeenumber', 'environmentsatisfaction_cat', 'gender', 'gender_cat',
#        'jobinvolvement', 'jobinvolvement_cat', 'joblevel', 'jobrole',
#        'jobsatisfaction', 'maritalstatus', 'monthlyrate', 'numcompaniesworked',
#        'overtime', 'percentsalaryhike', 'relationshipsatisfaction',
#        'relationshipsatisfaction_cat', 'stockoptionlevel',
#        'trainingtimeslastyear', 'worklifebalance_cat', 'yearsatcompany',
#        'yearssincelastpromotion', 'yearswithcurrmanager', 'remotework',
#        'attrition_number', 'environmentsatisfaction', 'hourlyrate',
#        'totalworkingyears', 'worklifebalance'],
#       dtype='object')

# %% [markdown]
# # FASE 3. INSERCIÓN DE DATOS

# %%
definitivo.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'education_cat', 'educationfield',
#        'employeenumber', 'environmentsatisfaction_cat', 'gender', 'gender_cat',
#        'jobinvolvement', 'jobinvolvement_cat', 'joblevel', 'jobrole',
#        'jobsatisfaction', 'maritalstatus', 'monthlyrate', 'numcompaniesworked',
#        'overtime', 'percentsalaryhike', 'relationshipsatisfaction',
#        'relationshipsatisfaction_cat', 'stockoptionlevel',
#        'trainingtimeslastyear', 'worklifebalance_cat', 'yearsatcompany',
#        'yearssincelastpromotion', 'yearswithcurrmanager', 'remotework',
#        'attrition_number', 'environmentsatisfaction', 'hourlyrate',
#        'totalworkingyears', 'worklifebalance'],
#       dtype='object')

# %%
df_abandono = definitivo[['attrition', 'environmentsatisfaction', 'environmentsatisfaction_cat', 'jobinvolvement', 'jobinvolvement_cat', 'jobsatisfaction','relationshipsatisfaction', 'relationshipsatisfaction_cat', 'worklifebalance', 'worklifebalance_cat', 'employeenumber']]
df_abandono
# Out:
#      attrition  environmentsatisfaction environmentsatisfaction_cat  \
# 0           No                      1.0                     nothing
# 1           No                      3.0                      medium
# 2           No                      3.0                      medium
# 5           No                      4.0                     maximun
# 6           No                      1.0                     nothing
# ...        ...                      ...                         ...
# 1605        No                      2.0                      little
# 1606        No                      3.0                      medium
# 1608        No                      3.0                      medium
# 1610        No                      3.0                      medium
# 1613        No                      4.0                     maximun
#
#       jobinvolvement jobinvolvement_cat  jobsatisfaction  \
# 0                  3           involved                3
# 1                  2    little involved                3
# 2                  3           involved                4
# 5                  3           involved                4
# 6                  3           involved                1
# ...              ...                ...              ...
# 1605               2    little involved                3
# 1606               2    little involved                1
# 1608               3           involved                1
# 1610               3           involved                2
# 1613               3           involved                3
#
#       relationshipsatisfaction relationshipsatisfaction_cat  worklifebalance  \
# 0                            3                       medium         3.000000
# 1                            1                      nothing         3.000000
# 2                            4                      maximun         2.760507
# 5                            2                       little         3.000000
# 6                            4                      maximun         2.000000
# ...                        ...                          ...              ...
# 1605                         2                       little         4.000000
# 1606                         2                       little         3.000000
# 1608                         3                       medium         4.000000
# 1610                         2                       little         2.000000
# 1613                         2                       little         3.000000
#
#      worklifebalance_cat  employeenumber
# 0                 medium           162.0
# 1                 medium           259.0
# 2                unknown           319.0
# 5                 medium          1900.0
# 6                 little            81.0
# ...                  ...             ...
# 1605             maximun           941.0
# 1606              medium           956.0
# 1608             maximun           966.0
# 1610              little           972.0
# 1613              medium             NaN
#
# [1080 rows x 11 columns]

# %%
lista_tuplas_abandono = [tuple(x) for x in df_abandono.values]
lista_tuplas_abandono
# Out:
# [('No', 1.0, 'nothing', 3, 'involved', 3, 3, 'medium', 3.0, 'medium', 162.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   3,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   259.0),
#  ('No',
#   3.0,
#   'medium',
#   3,
#   'involved',
#   4,
#   4,
#   'maximun',
#   2.7605066804848613,
#   'unknown',
#   319.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 2, 'little', 3.0, 'medium', 1900.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 1, 4, 'maximun', 2.0, 'little', 81.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 3, 'medium', 3.0, 'medium', 387.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 3, 2, 'little', 4.0, 'maximun', 999.0),
#  ('No',
#   2.0,
#   'little',
#   1,
#   'not involved',
#   3,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1035.0),
#  ('Yes', 2.0, 'little', 3, 'involved', 3, 4, 'maximun', 3.0, 'medium', 58.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 4, 'maximun', 3.0, 'medium', 558.0),
#  ('Yes', 4.0, 'maximun', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 825.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   1712.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 73.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 3, 'medium', 2.0, 'little', 820.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 1294.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 3, 'medium', 3.0, 'medium', 1774.0),
#  ('No',
#   2.6617129518442466,
#   'unknown',
#   3,
#   'involved',
#   3,
#   4,
#   'maximun',
#   4.0,
#   'maximun',
#   1815.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 3, 2, 'little', 3.0, 'medium', 1993.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 4, 'maximun', 2.0, 'little', 32.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   1,
#   2,
#   'little',
#   3.0,
#   'medium',
#   100.0),
#  ('No', 2.0, 'little', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 244.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 327.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 373.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   729.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   830.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 3, 'medium', 4.0, 'maximun', 981.0),
#  ('Yes',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1042.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   1,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1080.0),
#  ('No',
#   4.0,
#   'maximun',
#   3,
#   'involved',
#   2,
#   1,
#   'nothing',
#   2.771501666283053,
#   'unknown',
#   1995.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   1,
#   3,
#   'medium',
#   2.0,
#   'little',
#   145.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 4, 'maximun', 4.0, 'maximun', 158.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 2, 'little', 3.0, 'medium', 391.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   2,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   436.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 4, 'maximun', 4.0, 'maximun', 1527.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1866.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 1, 'nothing', 2.0, 'little', 2026.0),
#  ('No',
#   2.0,
#   'little',
#   1,
#   'not involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   107.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 3, 'medium', 2.0, 'little', 170.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   1,
#   'nothing',
#   2.0,
#   'little',
#   215.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 2, 4, 'maximun', 4.0, 'maximun', 304.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 1, 'nothing', 3.0, 'medium', 529.0),
#  ('No',
#   2.0,
#   'little',
#   1,
#   'not involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   691.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 3, 'medium', 1.0, 'nothing', 692.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 4, 'maximun', 3.0, 'medium', 1005.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   3,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1024.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   4,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1039.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 2, 'little', 3.0, 'medium', 1225.0),
#  ('No',
#   2.6328352471898637,
#   'unknown',
#   4,
#   'very involved',
#   3,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1375.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   3,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1661.0),
#  ('No',
#   4.0,
#   'maximun',
#   3,
#   'involved',
#   4,
#   4,
#   'maximun',
#   2.771660556666124,
#   'unknown',
#   1668.0),
#  ('No',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   2,
#   4,
#   'maximun',
#   2.769690420786552,
#   'unknown',
#   1698.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   2,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1937.0),
#  ('No',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   4,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   2017.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   117.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 3, 'medium', 2.0, 'little', 131.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   1,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   153.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 3, 3, 'medium', 2.0, 'little', 307.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 374.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   2,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   899.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 3, 'medium', 2.0, 'little', 1014.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1117.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 2, 'little', 3.0, 'medium', 1238.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   1,
#   'not involved',
#   2,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1277.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   3,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1666.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   2.763869682554192,
#   'unknown',
#   1696.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 1805.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1932.0),
#  ('No',
#   2.802736301596593,
#   'unknown',
#   3,
#   'involved',
#   4,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   2016.0),
#  ('No',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   20.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 4, 'maximun', 1.0, 'nothing', 184.0),
#  ('No',
#   2.0,
#   'little',
#   3,
#   'involved',
#   2,
#   3,
#   'medium',
#   2.76166072677983,
#   'unknown',
#   206.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 228.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 239.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   3,
#   3,
#   'medium',
#   2.0,
#   'little',
#   256.0),
#  ('No',
#   2.651053989312877,
#   'unknown',
#   2,
#   'little involved',
#   1,
#   2,
#   'little',
#   3.0,
#   'medium',
#   339.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 3, 'medium', 2.0, 'little', 406.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 4, 'maximun', 3.0, 'medium', 429.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   444.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 452.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   456.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   4,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   481.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   3,
#   2,
#   'little',
#   3.0,
#   'medium',
#   513.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 597.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 3, 'medium', 3.0, 'medium', 600.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 2, 'little', 3.0, 'medium', 630.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   638.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 4, 'maximun', 2.0, 'little', 683.0),
#  ('Yes', 4.0, 'maximun', 3, 'involved', 4, 3, 'medium', 2.0, 'little', 780.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 4, 'maximun', 4.0, 'maximun', 817.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 901.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 2, 3, 'medium', 2.0, 'little', 944.0),
#  ('No',
#   2.7237222935927106,
#   'unknown',
#   3,
#   'involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   984.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   3,
#   1,
#   'nothing',
#   2.0,
#   'little',
#   1088.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 3, 4, 'maximun', 3.0, 'medium', 1124.0),
#  ('Yes',
#   2.8153418021487093,
#   'unknown',
#   3,
#   'involved',
#   1,
#   2,
#   'little',
#   2.0,
#   'little',
#   1167.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1184.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   1,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1252.0),
#  ('No', 2.0, 'little', 3, 'involved', 2, 3, 'medium', 3.0, 'medium', 1267.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   2,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1278.0),
#  ('No',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   1,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   1288.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   2,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1307.0),
#  ('No',
#   4.0,
#   'maximun',
#   1,
#   'not involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1336.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 2, 'little', 3.0, 'medium', 1352.0),
#  ('Yes',
#   2.777729243553374,
#   'unknown',
#   2,
#   'little involved',
#   1,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   1360.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   1,
#   1,
#   'nothing',
#   2.0,
#   'little',
#   1419.0),
#  ('No',
#   4.0,
#   'maximun',
#   1,
#   'not involved',
#   1,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1478.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 1480.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   2,
#   3,
#   'medium',
#   4.0,
#   'maximun',
#   1489.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 1520.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1535.0),
#  ('No',
#   2.0,
#   'little',
#   3,
#   'involved',
#   1,
#   4,
#   'maximun',
#   2.773167035100017,
#   'unknown',
#   1586.0),
#  ('No',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   3,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   1596.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   3,
#   'involved',
#   4,
#   1,
#   'nothing',
#   4.0,
#   'maximun',
#   1667.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1701.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 1706.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 3, 2, 'little', 3.0, 'medium', 1971.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1976.0),
#  ('No',
#   4.0,
#   'maximun',
#   3,
#   'involved',
#   3,
#   1,
#   'nothing',
#   4.0,
#   'maximun',
#   1985.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   3,
#   'involved',
#   3,
#   4,
#   'maximun',
#   1.0,
#   'nothing',
#   2032.0),
#  ('No',
#   2.748475031312557,
#   'unknown',
#   2,
#   'little involved',
#   4,
#   1,
#   'nothing',
#   2.0,
#   'little',
#   2056.0),
#  ('No',
#   3.0,
#   'medium',
#   3,
#   'involved',
#   4,
#   4,
#   'maximun',
#   2.7640992556390023,
#   'unknown',
#   57.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 2, 'little', 3.0, 'medium', 78.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   2.763615382331551,
#   'unknown',
#   104.0),
#  ('Yes',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   118.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   2,
#   2,
#   'little',
#   2.0,
#   'little',
#   121.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 1, 'nothing', 3.0, 'medium', 125.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 4, 'maximun', 3.0, 'medium', 207.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 3, 1, 'nothing', 3.0, 'medium', 227.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 2, 'little', 3.0, 'medium', 253.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   264.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   1,
#   'not involved',
#   4,
#   3,
#   'medium',
#   2.0,
#   'little',
#   291.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   292.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 306.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 335.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   3,
#   3,
#   'medium',
#   2.0,
#   'little',
#   420.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   2,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   421.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 4, 'maximun', 3.0, 'medium', 441.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 3, 'medium', 3.0, 'medium', 531.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 1, 4, 'maximun', 1.0, 'nothing', 549.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 567.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 4, 'maximun', 4.0, 'maximun', 581.0),
#  ('Yes', 1.0, 'nothing', 3, 'involved', 1, 1, 'nothing', 3.0, 'medium', 702.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   716.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 4, 'maximun', 3.0, 'medium', 772.0),
#  ('No', 2.0, 'little', 3, 'involved', 2, 4, 'maximun', 2.0, 'little', 836.0),
#  ('Yes', 3.0, 'medium', 3, 'involved', 4, 1, 'nothing', 4.0, 'maximun', 840.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   844.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   867.0),
#  ('No', 2.0, 'little', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 889.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 1, 'nothing', 2.0, 'little', 924.0),
#  ('No',
#   4.0,
#   'maximun',
#   3,
#   'involved',
#   4,
#   2,
#   'little',
#   2.76296243941166,
#   'unknown',
#   976.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 4, 'maximun', 3.0, 'medium', 992.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 1002.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   2.0,
#   'little',
#   1073.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   2,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1138.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 1192.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   2.0,
#   'little',
#   1196.0),
#  ('No',
#   3.0,
#   'medium',
#   1,
#   'not involved',
#   4,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1315.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 1, 'nothing', 2.0, 'little', 1324.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 4, 'maximun', 2.0, 'little', 1334.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 1346.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 4, 'maximun', 4.0, 'maximun', 1356.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 1423.0),
#  ('Yes',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   2,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1459.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   2,
#   2,
#   'little',
#   2.0,
#   'little',
#   1472.0),
#  ('No', 2.0, 'little', 3, 'involved', 1, 4, 'maximun', 2.0, 'little', 1485.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 1543.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 3, 'medium', 1.0, 'nothing', 1547.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 2, 1, 'nothing', 3.0, 'medium', 1553.0),
#  ('Yes',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   1,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1562.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 1582.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 3, 'medium', 3.0, 'medium', 1606.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 2, 3, 'medium', 3.0, 'medium', 1658.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 3, 'medium', 3.0, 'medium', 1665.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 4, 'maximun', 3.0, 'medium', 1737.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 4, 'maximun', 3.0, 'medium', 1790.0),
#  ('No',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1823.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 3, 'medium', 2.0, 'little', 1857.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1864.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 1, 'nothing', 3.0, 'medium', 1881.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   1888.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 1, 'nothing', 2.0, 'little', 1950.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 4, 'maximun', 3.0, 'medium', 1962.0),
#  ('No', 2.0, 'little', 3, 'involved', 1, 1, 'nothing', 3.0, 'medium', 1975.0),
#  ('No', 2.0, 'little', 3, 'involved', 2, 3, 'medium', 3.0, 'medium', 1986.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 1, 'nothing', 1.0, 'nothing', 2000.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   2,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   2.0),
#  ('No',
#   2.765692002648665,
#   'unknown',
#   3,
#   'involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   5.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 35.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 4, 'maximun', 2.0, 'little', 76.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 4, 'maximun', 3.0, 'medium', 98.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 4, 'maximun', 1.0, 'nothing', 120.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   1,
#   'not involved',
#   3,
#   4,
#   'maximun',
#   2.767284753642839,
#   'unknown',
#   147.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 154.0),
#  ('No',
#   1.0,
#   'nothing',
#   1,
#   'not involved',
#   3,
#   3,
#   'medium',
#   2.0,
#   'little',
#   159.0),
#  ('No',
#   2.603204527362614,
#   'unknown',
#   3,
#   'involved',
#   2,
#   1,
#   'nothing',
#   4.0,
#   'maximun',
#   160.0),
#  ('Yes',
#   2.0,
#   'little',
#   1,
#   'not involved',
#   3,
#   2,
#   'little',
#   2.0,
#   'little',
#   163.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 3, 'medium', 3.0, 'medium', 176.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 4, 'maximun', 3.0, 'medium', 177.0),
#  ('No',
#   4.0,
#   'maximun',
#   1,
#   'not involved',
#   4,
#   4,
#   'maximun',
#   4.0,
#   'maximun',
#   195.0),
#  ('No', 2.0, 'little', 3, 'involved', 2, 1, 'nothing', 3.0, 'medium', 202.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 4, 'maximun', 1.0, 'nothing', 205.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 252.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 2, 3, 'medium', 3.0, 'medium', 258.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 2, 4, 'maximun', 2.0, 'little', 260.0),
#  ('No',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   1,
#   1,
#   'nothing',
#   2.0,
#   'little',
#   267.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 275.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 4, 'maximun', 3.0, 'medium', 293.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   302.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 1, 'nothing', 4.0, 'maximun', 314.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   4.0,
#   'maximun',
#   329.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   361.0),
#  ('No',
#   2.708116012424604,
#   'unknown',
#   1,
#   'not involved',
#   2,
#   2,
#   'little',
#   2.0,
#   'little',
#   363.0),
#  ('No',
#   2.0,
#   'little',
#   3,
#   'involved',
#   4,
#   1,
#   'nothing',
#   2.759840829784334,
#   'unknown',
#   388.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   483.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 595.0),
#  ('Yes',
#   2.0,
#   'little',
#   3,
#   'involved',
#   3,
#   2,
#   'little',
#   2.765353485500143,
#   'unknown',
#   608.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   3,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   616.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   3,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   721.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 4, 'maximun', 2.0, 'little', 722.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 3, 'medium', 2.0, 'little', 733.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   3,
#   2,
#   'little',
#   3.0,
#   'medium',
#   734.0),
#  ('No',
#   2.0,
#   'little',
#   1,
#   'not involved',
#   3,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   783.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 1, 'nothing', 2.0, 'little', 793.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 2, 'little', 2.0, 'little', 809.0),
#  ('Yes',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   967.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 4, 'maximun', 3.0, 'medium', 990.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 3, 'medium', 3.0, 'medium', 1013.0),
#  ('No',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   1,
#   3,
#   'medium',
#   2.0,
#   'little',
#   1015.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1018.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 1034.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 2, 'little', 3.0, 'medium', 1046.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   2,
#   1,
#   'nothing',
#   2.751449305714984,
#   'unknown',
#   1050.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   1,
#   2,
#   'little',
#   4.0,
#   'maximun',
#   1074.0),
#  ('Yes',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   1,
#   1,
#   'nothing',
#   2.0,
#   'little',
#   1082.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 4, 'maximun', 4.0, 'maximun', 1097.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   3,
#   'involved',
#   1,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1100.0),
#  ('Yes',
#   2.777677857438896,
#   'unknown',
#   2,
#   'little involved',
#   3,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1101.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   3,
#   'involved',
#   4,
#   2,
#   'little',
#   4.0,
#   'maximun',
#   1106.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   3,
#   2,
#   'little',
#   2.7676226758345472,
#   'unknown',
#   1119.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 1126.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   3,
#   1,
#   'nothing',
#   2.760023591424541,
#   'unknown',
#   1128.0),
#  ('No',
#   1.0,
#   'nothing',
#   4,
#   'very involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1177.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   2,
#   2,
#   'little',
#   4.0,
#   'maximun',
#   1182.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 2, 'little', 3.0, 'medium', 1201.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 4, 'maximun', 3.0, 'medium', 1218.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 1, 'nothing', 2.0, 'little', 1220.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 1, 'nothing', 2.0, 'little', 1224.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 4, 'maximun', 3.0, 'medium', 1235.0),
#  ('No',
#   3.0,
#   'medium',
#   1,
#   'not involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1237.0),
#  ('No',
#   3.0,
#   'medium',
#   1,
#   'not involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1255.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   2.0,
#   'little',
#   1264.0),
#  ('No',
#   2.7192208190717406,
#   'unknown',
#   3,
#   'involved',
#   4,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   1283.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   4.0,
#   'maximun',
#   1293.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   3,
#   'involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1295.0),
#  ('No',
#   1.0,
#   'nothing',
#   3,
#   'involved',
#   3,
#   1,
#   'nothing',
#   2.7559391271257967,
#   'unknown',
#   1322.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 4, 'maximun', 2.0, 'little', 1344.0),
#  ('No', 2.0, 'little', 3, 'involved', 1, 4, 'maximun', 3.0, 'medium', 1355.0),
#  ('No',
#   2.6523540482355887,
#   'unknown',
#   4,
#   'very involved',
#   1,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   1362.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1369.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 1, 'nothing', 3.0, 'medium', 1377.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   3,
#   1,
#   'nothing',
#   1.0,
#   'nothing',
#   1402.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 1408.0),
#  ('No',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   1,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1417.0),
#  ('Yes', 3.0, 'medium', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 1421.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 4, 'maximun', 2.0, 'little', 1422.0),
#  ('No',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   4,
#   4,
#   'maximun',
#   4.0,
#   'maximun',
#   1424.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   3,
#   'involved',
#   4,
#   1,
#   'nothing',
#   4.0,
#   'maximun',
#   1457.0),
#  ('No',
#   2.0,
#   'little',
#   1,
#   'not involved',
#   1,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1460.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 2, 'little', 3.0, 'medium', 1484.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1497.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   1,
#   3,
#   'medium',
#   1.0,
#   'nothing',
#   1522.0),
#  ('No',
#   3.0,
#   'medium',
#   1,
#   'not involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1544.0),
#  ('Yes',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1572.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 4, 'maximun', 2.0, 'little', 1608.0),
#  ('No',
#   3.0,
#   'medium',
#   1,
#   'not involved',
#   1,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1611.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   1,
#   1,
#   'nothing',
#   2.7625971758748293,
#   'unknown',
#   1612.0),
#  ('No',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   4,
#   1,
#   'nothing',
#   2.7602303764679923,
#   'unknown',
#   1615.0),
#  ('No',
#   2.7164441366797245,
#   'unknown',
#   2,
#   'little involved',
#   1,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1619.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1635.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 1642.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1653.0),
#  ('Yes', 4.0, 'maximun', 3, 'involved', 3, 3, 'medium', 3.0, 'medium', 1691.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 1693.0),
#  ('No',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1703.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 1727.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 2, 'little', 3.0, 'medium', 1728.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   1,
#   4,
#   'maximun',
#   2.771183885516911,
#   'unknown',
#   1745.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   1,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1754.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 2, 4, 'maximun', 2.0, 'little', 1756.0),
#  ('No', 2.0, 'little', 3, 'involved', 2, 2, 'little', 3.0, 'medium', 1764.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 1849.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1927.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 3, 'medium', 4.0, 'maximun', 1934.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 3, 'medium', 2.0, 'little', 1951.0),
#  ('No',
#   3.0,
#   'medium',
#   3,
#   'involved',
#   1,
#   4,
#   'maximun',
#   2.776975417796804,
#   'unknown',
#   1952.0),
#  ('No',
#   4.0,
#   'maximun',
#   3,
#   'involved',
#   4,
#   1,
#   'nothing',
#   2.7602063530647483,
#   'unknown',
#   1965.0),
#  ('Yes', 1.0, 'nothing', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 1967.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 3, 'medium', 4.0, 'maximun', 1979.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 2, 'little', 3.0, 'medium', 2008.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 2009.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 2014.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   2,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   2034.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   2035.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   1,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   2062.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 2, 3, 'medium', 3.0, 'medium', 28.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 62.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   1,
#   2,
#   'little',
#   2.0,
#   'little',
#   199.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 4, 'maximun', 3.0, 'medium', 343.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   351.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 2, 2, 'little', 3.0, 'medium', 428.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 464.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   2.0,
#   'little',
#   731.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   1,
#   1,
#   'nothing',
#   1.0,
#   'nothing',
#   764.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 3, 3, 'medium', 2.0, 'little', 851.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 903.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 1, 4, 'maximun', 3.0, 'medium', 905.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 4, 'maximun', 1.0, 'nothing', 942.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1026.0),
#  ('No',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1085.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 4, 'maximun', 3.0, 'medium', 1109.0),
#  ('No',
#   2.0,
#   'little',
#   3,
#   'involved',
#   2,
#   4,
#   'maximun',
#   2.7707267165835217,
#   'unknown',
#   1118.0),
#  ('No',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   3,
#   4,
#   'maximun',
#   4.0,
#   'maximun',
#   1152.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 2, 'little', 3.0, 'medium', 1350.0),
#  ('No',
#   3.0,
#   'medium',
#   1,
#   'not involved',
#   2,
#   2,
#   'little',
#   2.0,
#   'little',
#   1514.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 3, 'medium', 4.0, 'maximun', 1523.0),
#  ('No',
#   3.0,
#   'medium',
#   1,
#   'not involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1539.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   3,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1588.0),
#  ('No',
#   2.6465586941124566,
#   'unknown',
#   3,
#   'involved',
#   1,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   1617.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   2,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1719.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   1,
#   4,
#   'maximun',
#   2.7704334408651565,
#   'unknown',
#   1870.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 3, 1, 'nothing', 2.0, 'little', 2031.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   2,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   2065.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   15.0),
#  ('No',
#   2.6988252318125125,
#   'unknown',
#   3,
#   'involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   60.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   2,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   85.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 346.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 1, 'nothing', 1.0, 'nothing', 384.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 4, 'maximun', 3.0, 'medium', 498.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   4.0,
#   'maximun',
#   551.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 3, 'medium', 4.0, 'maximun', 604.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 626.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 2, 3, 'medium', 3.0, 'medium', 644.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   649.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   714.0),
#  ('No',
#   2.858405287462364,
#   'unknown',
#   3,
#   'involved',
#   4,
#   2,
#   'little',
#   2.0,
#   'little',
#   781.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   804.0),
#  ('No',
#   2.770700732910424,
#   'unknown',
#   2,
#   'little involved',
#   1,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   856.0),
#  ('No',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   2,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   998.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 1120.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 2, 4, 'maximun', 2.0, 'little', 1143.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 4, 'maximun', 2.0, 'little', 1251.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 3, 'medium', 2.0, 'little', 1438.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 2, 'little', 2.0, 'little', 1574.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 2, 3, 'medium', 2.0, 'little', 1671.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 94.0),
#  ('No',
#   4.0,
#   'maximun',
#   1,
#   'not involved',
#   4,
#   1,
#   'nothing',
#   2.0,
#   'little',
#   112.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 2, 'little', 4.0, 'maximun', 129.0),
#  ('Yes',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   142.0),
#  ('Yes', 2.0, 'little', 3, 'involved', 2, 1, 'nothing', 3.0, 'medium', 161.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   2,
#   3,
#   'medium',
#   2.0,
#   'little',
#   164.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   3,
#   'involved',
#   1,
#   1,
#   'nothing',
#   4.0,
#   'maximun',
#   190.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 3, 3, 'medium', 2.0, 'little', 194.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 2, 'little', 3.0, 'medium', 226.0),
#  ('No',
#   3.0,
#   'medium',
#   3,
#   'involved',
#   3,
#   1,
#   'nothing',
#   2.7608987997157346,
#   'unknown',
#   231.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 1, 'nothing', 4.0, 'maximun', 240.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   4,
#   4,
#   'maximun',
#   4.0,
#   'maximun',
#   262.0),
#  ('Yes', 2.0, 'little', 3, 'involved', 4, 4, 'maximun', 2.0, 'little', 283.0),
#  ('No',
#   3.0,
#   'medium',
#   1,
#   'not involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   308.0),
#  ('Yes', 3.0, 'medium', 3, 'involved', 4, 3, 'medium', 1.0, 'nothing', 325.0),
#  ('Yes',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   2,
#   2,
#   'little',
#   4.0,
#   'maximun',
#   355.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 2, 'little', 4.0, 'maximun', 378.0),
#  ('No',
#   3.0,
#   'medium',
#   3,
#   'involved',
#   2,
#   4,
#   'maximun',
#   2.7690110322188395,
#   'unknown',
#   449.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   2,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   466.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 2, 'little', 3.0, 'medium', 486.0),
#  ('Yes',
#   2.7112182703790686,
#   'unknown',
#   2,
#   'little involved',
#   3,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   492.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 505.0),
#  ('Yes', 3.0, 'medium', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 510.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   527.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 3, 2, 'little', 3.0, 'medium', 547.0),
#  ('No',
#   3.0,
#   'medium',
#   1,
#   'not involved',
#   4,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   548.0),
#  ('No',
#   4.0,
#   'maximun',
#   1,
#   'not involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   577.0),
#  ('No',
#   1.0,
#   'nothing',
#   3,
#   'involved',
#   4,
#   4,
#   'maximun',
#   2.7764008352296163,
#   'unknown',
#   679.0),
#  ('Yes',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   785.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   2.0,
#   'little',
#   861.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 864.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   878.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 2, 'little', 3.0, 'medium', 895.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 2, 'little', 3.0, 'medium', 900.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   3,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   936.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 3, 'medium', 2.0, 'little', 997.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 3, 'medium', 1.0, 'nothing', 1048.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 3, 2, 'little', 3.0, 'medium', 1071.0),
#  ('No',
#   1.0,
#   'nothing',
#   4,
#   'very involved',
#   4,
#   3,
#   'medium',
#   2.0,
#   'little',
#   1116.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 3, 'medium', 2.0, 'little', 1132.0),
#  ('No',
#   2.0,
#   'little',
#   3,
#   'involved',
#   1,
#   4,
#   'maximun',
#   2.760150741535861,
#   'unknown',
#   1171.0),
#  ('Yes', 3.0, 'medium', 3, 'involved', 3, 3, 'medium', 3.0, 'medium', 1200.0),
#  ('No',
#   2.0,
#   'little',
#   1,
#   'not involved',
#   4,
#   1,
#   'nothing',
#   2.0,
#   'little',
#   1202.0),
#  ('No',
#   4.0,
#   'maximun',
#   3,
#   'involved',
#   3,
#   1,
#   'nothing',
#   1.0,
#   'nothing',
#   1245.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   2,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1280.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   3,
#   'involved',
#   3,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1309.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1374.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   4.0,
#   'maximun',
#   1390.0),
#  ('No',
#   2.7409534750842024,
#   'unknown',
#   3,
#   'involved',
#   4,
#   1,
#   'nothing',
#   4.0,
#   'maximun',
#   1395.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 2, 'little', 3.0, 'medium', 1397.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 3, 'medium', 1.0, 'nothing', 1409.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 1425.0),
#  ('No',
#   2.7218305586519813,
#   'unknown',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   2.0,
#   'little',
#   1435.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 3, 'medium', 3.0, 'medium', 1445.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 4, 'maximun', 3.0, 'medium', 1469.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 3, 'medium', 2.0, 'little', 1503.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   3,
#   'involved',
#   1,
#   2,
#   'little',
#   1.0,
#   'nothing',
#   1534.0),
#  ('No',
#   2.594345902381025,
#   'unknown',
#   3,
#   'involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1546.0),
#  ('No',
#   1.0,
#   'nothing',
#   3,
#   'involved',
#   1,
#   4,
#   'maximun',
#   4.0,
#   'maximun',
#   1548.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 1598.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   2,
#   3,
#   'medium',
#   2.773532558380432,
#   'unknown',
#   1599.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   2,
#   2,
#   'little',
#   2.0,
#   'little',
#   1609.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   4.0,
#   'maximun',
#   1638.0),
#  ('No', 2.0, 'little', 3, 'involved', 2, 1, 'nothing', 1.0, 'nothing', 1640.0),
#  ('No',
#   2.671936026110958,
#   'unknown',
#   4,
#   'very involved',
#   1,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1664.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   3,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1684.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   4.0,
#   'maximun',
#   1704.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 4, 'maximun', 2.0, 'little', 1736.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   3,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1782.0),
#  ('No',
#   2.0,
#   'little',
#   1,
#   'not involved',
#   3,
#   2,
#   'little',
#   4.0,
#   'maximun',
#   1826.0),
#  ('No',
#   2.714981998147394,
#   'unknown',
#   3,
#   'involved',
#   4,
#   3,
#   'medium',
#   2.0,
#   'little',
#   1850.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 3, 'medium', 3.0, 'medium', 1909.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 2, 'little', 2.0, 'little', 1924.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 4, 'maximun', 3.0, 'medium', 1941.0),
#  ('No',
#   1.0,
#   'nothing',
#   4,
#   'very involved',
#   2,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1949.0),
#  ('Yes',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   1,
#   2,
#   'little',
#   2.7718002379825872,
#   'unknown',
#   27.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   3,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   46.0),
#  ('No',
#   2.8242004271302976,
#   'unknown',
#   4,
#   'very involved',
#   1,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   52.0),
#  ('No', 2.0, 'little', 3, 'involved', 1, 3, 'medium', 2.0, 'little', 68.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 4, 'maximun', 3.0, 'medium', 79.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   80.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   91.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   2,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   119.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 3, 1, 'nothing', 1.0, 'nothing', 126.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   4,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   148.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 3, 'medium', 3.0, 'medium', 150.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   198.0),
#  ('No',
#   2.686287712280734,
#   'unknown',
#   3,
#   'involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   216.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   4.0,
#   'maximun',
#   230.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 2, 'little', 3.0, 'medium', 270.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 4, 'maximun', 4.0, 'maximun', 277.0),
#  ('Yes',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   1,
#   3,
#   'medium',
#   2.0,
#   'little',
#   299.0),
#  ('Yes',
#   2.630604050409371,
#   'unknown',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   2.775562430613851,
#   'unknown',
#   315.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 1, 'nothing', 3.0, 'medium', 330.0),
#  ('No',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   1,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   369.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 4, 'maximun', 2.0, 'little', 386.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 390.0),
#  ('No',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   412.0),
#  ('No',
#   4.0,
#   'maximun',
#   1,
#   'not involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   422.0),
#  ('No',
#   3.0,
#   'medium',
#   3,
#   'involved',
#   2,
#   2,
#   'little',
#   2.775320790535178,
#   'unknown',
#   434.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 4, 'maximun', 2.0, 'little', 450.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 1, 'nothing', 2.0, 'little', 469.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   491.0),
#  ('Yes', 1.0, 'nothing', 3, 'involved', 2, 2, 'little', 3.0, 'medium', 554.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   579.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 4, 'maximun', 2.0, 'little', 592.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 4, 'maximun', 3.0, 'medium', 599.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 2, 4, 'maximun', 4.0, 'maximun', 641.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   3,
#   3,
#   'medium',
#   2.0,
#   'little',
#   655.0),
#  ('Yes', 3.0, 'medium', 3, 'involved', 1, 2, 'little', 3.0, 'medium', 667.0),
#  ('No', 2.0, 'little', 3, 'involved', 1, 4, 'maximun', 4.0, 'maximun', 758.0),
#  ('No',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   2,
#   3,
#   'medium',
#   1.0,
#   'nothing',
#   760.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 791.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   1,
#   3,
#   'medium',
#   2.0,
#   'little',
#   796.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 2, 'little', 3.0, 'medium', 799.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 4, 'maximun', 3.0, 'medium', 815.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   827.0),
#  ('No',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   3,
#   3,
#   'medium',
#   2.0,
#   'little',
#   865.0),
#  ('No',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   4,
#   2,
#   'little',
#   2.0,
#   'little',
#   894.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 2, 'little', 3.0, 'medium', 983.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 4, 'maximun', 3.0, 'medium', 996.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 1011.0),
#  ('No',
#   2.0,
#   'little',
#   1,
#   'not involved',
#   1,
#   1,
#   'nothing',
#   2.0,
#   'little',
#   1019.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1032.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 2, 'little', 4.0, 'maximun', 1045.0),
#  ('No', 2.0, 'little', 3, 'involved', 2, 1, 'nothing', 3.0, 'medium', 1049.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1068.0),
#  ('No',
#   2.718720540444671,
#   'unknown',
#   2,
#   'little involved',
#   2,
#   1,
#   'nothing',
#   1.0,
#   'nothing',
#   1136.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   3,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1179.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   1,
#   'not involved',
#   3,
#   2,
#   'little',
#   2.0,
#   'little',
#   1188.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 1211.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 3, 'medium', 2.0, 'little', 1228.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   1,
#   1,
#   'nothing',
#   4.0,
#   'maximun',
#   1231.0),
#  ('No',
#   1.0,
#   'nothing',
#   3,
#   'involved',
#   3,
#   2,
#   'little',
#   2.769575244193008,
#   'unknown',
#   1259.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 2, 1, 'nothing', 3.0, 'medium', 1338.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 4, 'maximun', 3.0, 'medium', 1349.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1387.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   3,
#   2,
#   'little',
#   2.0,
#   'little',
#   1401.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1407.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   1,
#   1,
#   'nothing',
#   2.772917058675461,
#   'unknown',
#   1420.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 1431.0),
#  ('No',
#   4.0,
#   'maximun',
#   3,
#   'involved',
#   4,
#   3,
#   'medium',
#   2.7781358069773905,
#   'unknown',
#   1446.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 1, 'nothing', 3.0, 'medium', 1477.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   3,
#   'involved',
#   2,
#   1,
#   'nothing',
#   1.0,
#   'nothing',
#   1487.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 1, 'nothing', 4.0, 'maximun', 1499.0),
#  ('No',
#   2.5861075149375994,
#   'unknown',
#   3,
#   'involved',
#   3,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1533.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   2,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1545.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   3,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1554.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 3, 'medium', 3.0, 'medium', 1563.0),
#  ('No',
#   2.0,
#   'little',
#   1,
#   'not involved',
#   1,
#   2,
#   'little',
#   2.0,
#   'little',
#   1622.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 1, 'nothing', 2.0, 'little', 1631.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 1646.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 2, 3, 'medium', 3.0, 'medium', 1659.0),
#  ('No',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   4,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1689.0),
#  ('No',
#   3.0,
#   'medium',
#   1,
#   'not involved',
#   4,
#   3,
#   'medium',
#   2.0,
#   'little',
#   1700.0),
#  ('No',
#   4.0,
#   'maximun',
#   1,
#   'not involved',
#   3,
#   3,
#   'medium',
#   1.0,
#   'nothing',
#   1739.0),
#  ('No', 2.0, 'little', 3, 'involved', 2, 2, 'little', 2.0, 'little', 1768.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 2, 'little', 3.0, 'medium', 1772.0),
# ...
#   'involved',
#   4,
#   3,
#   'medium',
#   4.0,
#   'maximun',
#   42.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 53.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 1, 4, 'maximun', 3.0, 'medium', 54.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   1,
#   'not involved',
#   3,
#   3,
#   'medium',
#   2.0,
#   'little',
#   55.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   64.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   70.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 3, 'medium', 3.0, 'medium', 84.0),
#  ('No',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   97.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 4, 'maximun', 3.0, 'medium', 106.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 113.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   137.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   4.0,
#   'maximun',
#   139.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 144.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 155.0),
#  ('Yes', 4.0, 'maximun', 3, 'involved', 3, 4, 'maximun', 2.0, 'little', 167.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 4, 'maximun', 3.0, 'medium', 200.0),
#  ('No', 2.0, 'little', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 201.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   211.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   2,
#   2,
#   'little',
#   2.0,
#   'little',
#   214.0),
#  ('Yes',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   2.0,
#   'little',
#   243.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 2, 'little', 3.0, 'medium', 271.0),
#  ('Yes', 2.0, 'little', 3, 'involved', 1, 2, 'little', 3.0, 'medium', 282.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   309.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 3, 'medium', 2.0, 'little', 323.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 1, 'nothing', 2.0, 'little', 334.0),
#  ('Yes', 1.0, 'nothing', 3, 'involved', 3, 2, 'little', 3.0, 'medium', 342.0),
#  ('Yes', 1.0, 'nothing', 3, 'involved', 3, 3, 'medium', 1.0, 'nothing', 364.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   367.0),
#  ('Yes',
#   2.8292758687067003,
#   'unknown',
#   3,
#   'involved',
#   3,
#   4,
#   'maximun',
#   1.0,
#   'nothing',
#   392.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 397.0),
#  ('No',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   407.0),
#  ('Yes', 4.0, 'maximun', 3, 'involved', 3, 1, 'nothing', 2.0, 'little', 445.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 2, 'little', 3.0, 'medium', 468.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 3, 'medium', 3.0, 'medium', 471.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 3, 2, 'little', 1.0, 'nothing', 473.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   477.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 2, 'little', 3.0, 'medium', 479.0),
#  ('Yes', 4.0, 'maximun', 3, 'involved', 3, 2, 'little', 3.0, 'medium', 485.0),
#  ('No', 3.0, 'medium', 3, 'involved', 3, 3, 'medium', 4.0, 'maximun', 487.0),
#  ('Yes',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   2,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   494.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 1, 'nothing', 3.0, 'medium', 508.0),
#  ('Yes', 3.0, 'medium', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 514.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 4, 'maximun', 2.0, 'little', 518.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 556.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   4.0,
#   'maximun',
#   566.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   2.0,
#   'little',
#   568.0),
#  ('Yes', 2.0, 'little', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 614.0),
#  ('No',
#   3.0,
#   'medium',
#   1,
#   'not involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   615.0),
#  ('Yes',
#   3.0,
#   'medium',
#   1,
#   'not involved',
#   4,
#   2,
#   'little',
#   1.0,
#   'nothing',
#   622.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   2,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   643.0),
#  ('Yes',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   1,
#   3,
#   'medium',
#   4.0,
#   'maximun',
#   648.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 3, 'medium', 2.0, 'little', 656.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   2,
#   4,
#   'maximun',
#   4.0,
#   'maximun',
#   657.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   2.758209811941134,
#   'unknown',
#   661.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 4, 'maximun', 2.0, 'little', 662.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 1, 'nothing', 2.0, 'little', 690.0),
#  ('Yes', 4.0, 'maximun', 3, 'involved', 3, 4, 'maximun', 3.0, 'medium', 701.0),
#  ('No',
#   2.814659737725972,
#   'unknown',
#   2,
#   'little involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   704.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   4,
#   1,
#   'nothing',
#   2.7713631761197397,
#   'unknown',
#   715.0),
#  ('No',
#   3.0,
#   'medium',
#   3,
#   'involved',
#   3,
#   4,
#   'maximun',
#   2.77192858251338,
#   'unknown',
#   743.0),
#  ('No',
#   3.0,
#   'medium',
#   3,
#   'involved',
#   3,
#   3,
#   'medium',
#   2.770717775514185,
#   'unknown',
#   749.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 2, 'little', 1.0, 'nothing', 773.0),
#  ('No',
#   2.0,
#   'little',
#   3,
#   'involved',
#   1,
#   3,
#   'medium',
#   2.756121888766004,
#   'unknown',
#   775.0),
#  ('Yes',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   811.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   2,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   812.0),
#  ('Yes',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   1,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   816.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   832.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   2.0,
#   'little',
#   833.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   834.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 897.0),
#  ('No',
#   2.865992158902893,
#   'unknown',
#   3,
#   'involved',
#   2,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   904.0),
#  ('Yes', 1.0, 'nothing', 3, 'involved', 4, 3, 'medium', 1.0, 'nothing', 911.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   918.0),
#  ('Yes', 4.0, 'maximun', 3, 'involved', 4, 1, 'nothing', 2.0, 'little', 923.0),
#  ('No',
#   2.6392506286220923,
#   'unknown',
#   3,
#   'involved',
#   2,
#   2,
#   'little',
#   3.0,
#   'medium',
#   934.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   2,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   940.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 1, 'nothing', 2.0, 'little', 945.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   2,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   951.0),
#  ('Yes',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   2,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   952.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   2,
#   2,
#   'little',
#   2.0,
#   'little',
#   954.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   2,
#   2,
#   'little',
#   4.0,
#   'maximun',
#   959.0),
#  ('Yes',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   2,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   986.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   994.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 1003.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 4, 'maximun', 3.0, 'medium', 1012.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 2, 'little', 4.0, 'maximun', 1029.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   1,
#   'not involved',
#   2,
#   1,
#   'nothing',
#   1.0,
#   'nothing',
#   1033.0),
#  ('Yes', 1.0, 'nothing', 3, 'involved', 3, 2, 'little', 2.0, 'little', 1052.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 2, 2, 'little', 3.0, 'medium', 1056.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1076.0),
#  ('Yes',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   1,
#   1,
#   'nothing',
#   2.0,
#   'little',
#   1079.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   3,
#   'involved',
#   3,
#   3,
#   'medium',
#   4.0,
#   'maximun',
#   1081.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1105.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   2,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1111.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   3,
#   'involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1113.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1115.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 2, 3, 'medium', 3.0, 'medium', 1125.0),
#  ('Yes', 3.0, 'medium', 3, 'involved', 3, 4, 'maximun', 3.0, 'medium', 1156.0),
#  ('No',
#   2.0,
#   'little',
#   3,
#   'involved',
#   4,
#   1,
#   'nothing',
#   2.762362011743032,
#   'unknown',
#   1158.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   3,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1172.0),
#  ('No', 3.0, 'medium', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 1190.0),
#  ('No',
#   2.6834965315463046,
#   'unknown',
#   1,
#   'not involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1206.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   1,
#   1,
#   'nothing',
#   1.0,
#   'nothing',
#   1210.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 1242.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   3,
#   3,
#   'medium',
#   4.0,
#   'maximun',
#   1256.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   2,
#   3,
#   'medium',
#   2.0,
#   'little',
#   1258.0),
#  ('No', 3.0, 'medium', 3, 'involved', 4, 2, 'little', 3.0, 'medium', 1260.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   4.0,
#   'maximun',
#   1263.0),
#  ('No',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1269.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 4, 'maximun', 3.0, 'medium', 1270.0),
#  ('Yes',
#   3.0,
#   'medium',
#   1,
#   'not involved',
#   4,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1273.0),
#  ('No', 2.0, 'little', 3, 'involved', 2, 3, 'medium', 3.0, 'medium', 1306.0),
#  ('No',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1364.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 3, 'medium', 4.0, 'maximun', 1368.0),
#  ('Yes',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   3,
#   'medium',
#   4.0,
#   'maximun',
#   1379.0),
#  ('Yes',
#   2.0,
#   'little',
#   1,
#   'not involved',
#   3,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1427.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   2,
#   3,
#   'medium',
#   4.0,
#   'maximun',
#   1433.0),
#  ('No', 2.0, 'little', 3, 'involved', 1, 2, 'little', 4.0, 'maximun', 1434.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   1,
#   2,
#   'little',
#   4.0,
#   'maximun',
#   1458.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 3, 3, 'medium', 2.0, 'little', 1481.0),
#  ('No',
#   2.70642129751666,
#   'unknown',
#   3,
#   'involved',
#   3,
#   2,
#   'little',
#   2.0,
#   'little',
#   1482.0),
#  ('Yes', 2.0, 'little', 3, 'involved', 1, 3, 'medium', 2.0, 'little', 1494.0),
#  ('Yes',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   1,
#   3,
#   'medium',
#   2.0,
#   'little',
#   1504.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 1, 'nothing', 3.0, 'medium', 1515.0),
#  ('No', 2.0, 'little', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 1525.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   2,
#   2,
#   'little',
#   2.7674614734612017,
#   'unknown',
#   1542.0),
#  ('No',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   3,
#   1,
#   'nothing',
#   2.0,
#   'little',
#   1558.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   1,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1564.0),
#  ('No',
#   2.853333175935023,
#   'unknown',
#   3,
#   'involved',
#   4,
#   3,
#   'medium',
#   2.757207580591758,
#   'unknown',
#   1577.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 1, 'nothing', 3.0, 'medium', 1581.0),
#  ('No',
#   2.7531544831168864,
#   'unknown',
#   3,
#   'involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1591.0),
#  ('No',
#   3.0,
#   'medium',
#   2,
#   'little involved',
#   4,
#   4,
#   'maximun',
#   2.0,
#   'little',
#   1601.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   1,
#   2,
#   'little',
#   1.0,
#   'nothing',
#   1602.0),
#  ('Yes', 2.0, 'little', 3, 'involved', 4, 3, 'medium', 4.0, 'maximun', 1624.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   2,
#   2,
#   'little',
#   2.0,
#   'little',
#   1669.0),
#  ('No',
#   1.0,
#   'nothing',
#   3,
#   'involved',
#   4,
#   1,
#   'nothing',
#   2.7672346618597534,
#   'unknown',
#   1673.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 4, 'maximun', 3.0, 'medium', 1678.0),
#  ('No',
#   3.0,
#   'medium',
#   1,
#   'not involved',
#   4,
#   3,
#   'medium',
#   4.0,
#   'maximun',
#   1697.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   1,
#   'not involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1714.0),
#  ('No', 2.0, 'little', 3, 'involved', 1, 2, 'little', 3.0, 'medium', 1724.0),
#  ('No', 3.0, 'medium', 3, 'involved', 2, 4, 'maximun', 1.0, 'nothing', 1731.0),
#  ('No',
#   2.7631671592198166,
#   'unknown',
#   1,
#   'not involved',
#   3,
#   3,
#   'medium',
#   4.0,
#   'maximun',
#   1744.0),
#  ('No',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   4,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1755.0),
#  ('Yes', 1.0, 'nothing', 3, 'involved', 1, 3, 'medium', 2.0, 'little', 1758.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   3,
#   'involved',
#   3,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1761.0),
#  ('No',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   3,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1763.0),
#  ('No',
#   2.0,
#   'little',
#   1,
#   'not involved',
#   4,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1766.0),
#  ('Yes', 3.0, 'medium', 3, 'involved', 1, 3, 'medium', 3.0, 'medium', 1783.0),
#  ('No', 2.0, 'little', 3, 'involved', 3, 3, 'medium', 1.0, 'nothing', 1839.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   4,
#   'very involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1842.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 1847.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 3, 'medium', 4.0, 'maximun', 1853.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 3, 4, 'maximun', 3.0, 'medium', 1860.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   2,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1865.0),
#  ('No', 2.0, 'little', 3, 'involved', 2, 4, 'maximun', 3.0, 'medium', 1875.0),
#  ('Yes', 2.0, 'little', 3, 'involved', 4, 3, 'medium', 2.0, 'little', 1876.0),
#  ('No',
#   2.0,
#   'little',
#   2,
#   'little involved',
#   3,
#   3,
#   'medium',
#   2.0,
#   'little',
#   1893.0),
#  ('No',
#   2.0,
#   'little',
#   4,
#   'very involved',
#   1,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1903.0),
#  ('Yes',
#   3.0,
#   'medium',
#   4,
#   'very involved',
#   1,
#   4,
#   'maximun',
#   2.764031933788289,
#   'unknown',
#   1928.0),
#  ('Yes',
#   4.0,
#   'maximun',
#   3,
#   'involved',
#   3,
#   4,
#   'maximun',
#   3.0,
#   'medium',
#   1933.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   1,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1935.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 1, 4, 'maximun', 3.0, 'medium', 1936.0),
#  ('No', 4.0, 'maximun', 3, 'involved', 4, 3, 'medium', 2.0, 'little', 1938.0),
#  ('No', 2.0, 'little', 3, 'involved', 4, 3, 'medium', 3.0, 'medium', 1943.0),
#  ('Yes',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   2,
#   1,
#   'nothing',
#   3.0,
#   'medium',
#   1944.0),
#  ('No',
#   1.0,
#   'nothing',
#   2,
#   'little involved',
#   1,
#   1,
#   'nothing',
#   2.0,
#   'little',
#   1961.0),
#  ('No',
#   4.0,
#   'maximun',
#   2,
#   'little involved',
#   4,
#   2,
#   'little',
#   3.0,
#   'medium',
#   1966.0),
#  ('No',
#   4.0,
#   'maximun',
#   1,
#   'not involved',
#   4,
#   3,
#   'medium',
#   3.0,
#   'medium',
#   1974.0),
#  ('No', 1.0, 'nothing', 3, 'involved', 4, 3, 'medium', 2.0, 'little', 2012.0),
#  ...]

# %%
# cnx = mysql.connector.connect(user = "root",
#                               password = "AlumnaAdalab",
#                               host = "127.0.0.1",
#                               database = "mydb")#Nuesta base de datos de mysql
# #Nos permite enviar informacion atraves de la conexciosm
# mycursor = cnx.cursor()


# #Escribimos la query aqui
# #¡¡¡El ORDEN IMPORTA!!! --> El primer dato debe ser el primer elemento de la lista de tuplas
# sql_proyecto = "INSERT INTO abandono_satisfaccion (attrition, environmentsatisfaction, environmentsatisfaction_cat, jobinvolvement, jobinvolvement_cat, jobsatisfaction, relationshipsatisfaction, relationshipsatisfaction_cat, worklifebalance, worklifebalance_cat, employeenumber) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"

#                         #peliculas el nombre del archivo correspondiente
# try:
#     mycursor.executemany(sql_proyecto, lista_tuplas_abandono)
#     cnx.commit()
#     print(mycursor.rowcount,"registros insertados")
# except:
#     print("Ha habido un error en la inserción")

# %%
df_salario = definitivo[['dailyrate', 'monthlyrate', 'percentsalaryhike', 'hourlyrate', 'employeenumber']]
df_salario
# Out:
#       dailyrate  monthlyrate  percentsalaryhike  hourlyrate  employeenumber
# 0         684.0       6462.0                 13   51.000000           162.0
# 1         699.0       5678.0                 14   65.000000           259.0
# 2         532.0       4933.0                 11   58.000000           319.0
# 5         117.0       2437.0                 11   58.000000          1900.0
# 6        1435.0       2354.0                 11   99.000000            81.0
# ...         ...          ...                ...         ...             ...
# 1605      154.0      11737.0                 15   66.985591           941.0
# 1606     1283.0      11148.0                 12   52.000000           956.0
# 1608      498.0      13554.0                 12   93.000000           966.0
# 1610      805.0      23163.0                 12   57.000000           972.0
# 1613      566.0      24208.0                 13   75.000000             NaN
#
# [1080 rows x 5 columns]

# %% [markdown]
# # FASE 4. AB Testing

# %% [markdown]
# #### Establecer hipótesis
# - H0: No existe una relación entre el nivel de satisfacción en el trabajo y la rotación de empleados en la empresa. Se sospecha que los empleados con niveles de satisfacción más bajos tienen una mayor probabilidad de dejar la empresa
#
# #### Grupos
# - Control: Empleados con un nivel de satisfacción en el trabajo igual o superior a 3 en una escala de 1 a 5
# - Variante: Empleados con un nivel de satisfacción en el trabajo inferior a 3 en la misma escala
#
# ### Métrica
# - Attrition -- No: empleado no ha dejado la empresa; Yes: empleado ha dejado la empresa

# %%
#Paso1. Divide a los empleados en los grupos A y B según los criterios establecidos

df_control = definitivo[definitivo["jobsatisfaction"] >= 3]
df_variante = definitivo[definitivo["jobsatisfaction"] < 3]
print(len(df_control))
print(len(df_variante))
# Out:
# 665
# 415

# %%
# Paso2. Cálculo de la tasa de rotación

# Tasa de rotación en grupo de control
df_control_rotacion = df_control[df_control["attrition"] == "Yes"]
tasa_rotacion_control = df_control_rotacion.shape[0] / df_control.shape[0]
print(f"la tasa de rotación del grupo de control es:{tasa_rotacion_control}")

# Tasa de rotación en grupo variante
df_variante_rotacion = df_variante[df_variante["attrition"] == "Yes"]
tasa_rotacion_variante = df_variante_rotacion.shape[0] / df_variante.shape[0]
print(f"la tasa de rotación del grupo variante es:{tasa_rotacion_variante}")
# Out:
# la tasa de rotación del grupo de control es:0.14135338345864662
# la tasa de rotación del grupo variante es:0.2

# %%
# Gráfico para visualizar la diferencia en la tasa de rotación

# 1. De las tasas de conversión, creo un dataframe
rota = {"grupo":["control", "variante"], "tasa_rotacion": [0.14, 0.2]}
df_rotacion = pd.DataFrame(rota)

#2. Gráfica deacuerdo al df_rotacion
sns.barplot(x="grupo", y="tasa_rotacion", data=df_rotacion)
plt.title("Tasa de rotación");

# %%
#Creamos una columna con la división de los grupos por satisfacción
definitivo["group"] = np.where(definitivo["jobsatisfaction"] >= 3, "control", "variante")

# %% [markdown]
# Interpretación: La tasa de rotación es mayor en el grupo variante (aquellos con un nivel de satisfacción bajo = 1 ó 2)

# %%
#Realiza un análisis estadístico para determinar si hay una diferencia significativa en la tasa de rotación entre los grupos A y B.

#1. Creamos una columna con la división de los grupos por satisfacción
definitivo["group"] = np.where(definitivo["jobsatisfaction"] >= 3, "control", "variante")

#2. Tabla de contingencia
contingency_table = pd.crosstab(definitivo["group"], definitivo['attrition'])

#3.Realizar la prueba de proporciones
chi2, p_value, _, _ = chi2_contingency(contingency_table)
print(p_value)

#4. Imprimir el resultado de la prueba
alpha = 0.05
if p_value < alpha:
    print("Hay una diferencia significativa en la tasa de rotación de ambos grupos.")
    print("\n ---------- \n")
    print("""
          Los resultados sugieren que si que existe una diferencia entre los grupos 
          """)
else:
    print("No hay evidencia de una diferencia significativa en la tasa de rotación de ambos grupos.")
    print("\n ---------- \n")
    print(""" 
          Los resultados sugieren que no existe evidencia estadística para afirmar que las medias de las muestras son distintas
          """)
# Out:
# 0.014362771751750169
# Hay una diferencia significativa en la tasa de rotación de ambos grupos.
#
#  ----------
#
#
#           Los resultados sugieren que si que existe una diferencia entre los grupos

# %%
#contingency_table

# %%
# Paso 5. Calcular la magnitud de esta relación utilizando estadísticas como la diferencia de medias por ejemplo.

# %%
# REPRESENTACIÓN VISUAL
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 5),sharey=True)

#---Opción1------

# Gráfico 1: Rotación del grupo control
sns.countplot(x="jobsatisfaction", hue="attrition", data=df_control, ax=axes[0])
axes[0].set_title("Rotación grupo control")

# Gráfico 2: Rotación del grupo variante
sns.countplot(x="jobsatisfaction", hue="attrition", data=df_variante, ax=axes[1])
axes[1].set_title("Rotación grupo variante");

# %%
# ----- OPCIÓN 2 -----
#Gráfico 2 para mejor visualización entre ambos grupos

# Para q se vea mejor la diferencia entre el grupo de control y media, creamos una columna (es lo mismo que el filtrado hecho anteriormente entre grupo de control y variante pero esta vez en una nueva columna
definitivo["group"].value_counts()
sns.barplot(x="group", y="attrition_number", data=definitivo)
plt.title("Rotación según satisfacción");

# %% [markdown]
# Interpretación de los gráficos: Visualmente, la rotación es mayor en el grupo variante (aquellos con un nivel de satisfacción más bajo (1 y 2)) q en el control (donde el nivel de satisfacción es más alto (3 y 4))

# %%
definitivo.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'education_cat', 'educationfield',
#        'employeenumber', 'environmentsatisfaction_cat', 'gender', 'gender_cat',
#        'jobinvolvement', 'jobinvolvement_cat', 'joblevel', 'jobrole',
#        'jobsatisfaction', 'maritalstatus', 'monthlyrate', 'numcompaniesworked',
#        'overtime', 'percentsalaryhike', 'relationshipsatisfaction',
#        'relationshipsatisfaction_cat', 'stockoptionlevel',
#        'trainingtimeslastyear', 'worklifebalance_cat', 'yearsatcompany',
#        'yearssincelastpromotion', 'yearswithcurrmanager', 'remotework',
#        'attrition_number', 'environmentsatisfaction', 'hourlyrate',
#        'totalworkingyears', 'worklifebalance', 'group'],
#       dtype='object')

# %%
# Análisis estadístico para calcular la magnitud de esta relación utilizando estadísticas como la diferencia de medias por ejemplo
#--> Verificamos: Normalidad; Homogeneidad de Varianzas e Independencia

# %%
#A. NORMALIDAD (con Shapiro)

def normalidad(dataframe, columna):
    statistic, p_value = stats.shapiro(dataframe[columna])
    if p_value > 0.05:
        print(f"Para la columna {columna} los datos siguen una distribución normal.")
    else:
        print(f"Para la columna {columna} los datos no siguen una distribución normal.")

normalidad(definitivo, "attrition_number")
# Out:
# Para la columna attrition_number los datos no siguen una distribución normal.

# %%
#Puesto que nuestra métrica (attrition) no sigue una distribución normal, hacemos la prueba de ManWhitney 

#1. Filtramos el conjunto de datos para quedarnos con la métrica q queremos valorar
rotacion_control = df_control["attrition_number"]
rotacion_variante = df_variante["attrition_number"]
print(len(rotacion_control))
print(len(rotacion_variante))

#2. Realizamos la prueba de ManWhitney para calcular el pvalor
statistic, pvalue = mannwhitneyu(rotacion_control, rotacion_variante)
print(f"El pvalor de rotación es {pvalue}") 

if pvalue < 0.05:
    print("Para la métrica rotación, las medias son diferentes.")
else:
    print("Para la métrica rotación, las medias son iguales.")
# Out:
# 665
# 415
# El pvalor de rotación es 0.011366403739309406
# Para la métrica rotación, las medias son diferentes.

# %% [markdown]
# Interpretación del pvalor: Puesto que este pvalor es inferior a 0.05 podemos afirmar que existe una diferencia significativa entre las medias y por tanto podemos rechazar la hipótesis nula de que no existe una relación entre la rotación y el nivel de satisfacción.
# Conclusión: Existe una relación significativa entre el nivel de satisfacción y el abandono.

# %%
definitivo.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'education_cat', 'educationfield',
#        'employeenumber', 'environmentsatisfaction_cat', 'gender', 'gender_cat',
#        'jobinvolvement', 'jobinvolvement_cat', 'joblevel', 'jobrole',
#        'jobsatisfaction', 'maritalstatus', 'monthlyrate', 'numcompaniesworked',
#        'overtime', 'percentsalaryhike', 'relationshipsatisfaction',
#        'relationshipsatisfaction_cat', 'stockoptionlevel',
#        'trainingtimeslastyear', 'worklifebalance_cat', 'yearsatcompany',
#        'yearssincelastpromotion', 'yearswithcurrmanager', 'remotework',
#        'attrition_number', 'environmentsatisfaction', 'hourlyrate',
#        'totalworkingyears', 'worklifebalance', 'group'],
#       dtype='object')

# %%
df_control.head()
# Out:
#    age attrition businesstravel  dailyrate                department  \
# 0   51        No        Unknown      684.0                   Unknown
# 1   52        No        Unknown      699.0                   Unknown
# 2   42        No  travel_rarely      532.0   Research & Development
# 5   48        No        Unknown      117.0   Research & Development
# 7   42        No  travel_rarely      635.0                   Unknown
#
#    distancefromhome  education  education_cat    educationfield  \
# 0               6.0          3        college           Unknown
# 1               1.0          4        Unknown     life sciences
# 2               4.0          2    high school  technical degree
# 5              22.0          3        college           medical
# 7               1.0          1  middle school           Unknown
#
#    employeenumber environmentsatisfaction_cat  gender gender_cat  \
# 0           162.0                     nothing       0       male
# 1           259.0                      medium       0       male
# 2           319.0                      medium       0       male
# 5          1900.0                     maximun       1     female
# 7           387.0                      little       0       male
#
#    jobinvolvement jobinvolvement_cat  joblevel              jobrole  \
# 0               3           involved         5   research director
# 1               2    little involved         5             manager
# 2               3           involved         5             manager
# 5               3           involved         4             manager
# 7               3           involved         2     sales executive
#
#    jobsatisfaction maritalstatus  monthlyrate  numcompaniesworked overtime  \
# 0                3       Unknown       6462.0                   7       No
# 1                3       Unknown       5678.0                   0  Unknown
# 2                4       married       4933.0                   1       No
# 5                4       Unknown       2437.0                   3       No
# 7                3       married      24532.0                   1       No
#
#    percentsalaryhike  relationshipsatisfaction relationshipsatisfaction_cat  \
# 0                 13                         3                       medium
# 1                 14                         1                      nothing
# 2                 11                         4                      maximun
# 5                 11                         2                       little
# 7                 25                         3                       medium
#
#    stockoptionlevel  trainingtimeslastyear worklifebalance_cat  \
# 0                 0                      5              medium
# 1                 1                      5              medium
# 2                 0                      3             unknown
# 5                 1                      3              medium
# 7                 0                      3              medium
#
#    yearsatcompany  yearssincelastpromotion  yearswithcurrmanager remotework  \
# 0              20                       15                    15        Yes
# 1              33                       11                     9        Yes
# 2              22                       11                    15        Yes
# 5              22                        4                     7        Yes
# 7              20                       11                     6         No
#
#    attrition_number  environmentsatisfaction  hourlyrate  totalworkingyears  \
# 0                 0                      1.0        51.0          11.281973
# 1                 0                      3.0        65.0          34.000000
# 2                 0                      3.0        58.0          22.000000
# 5                 0                      4.0        58.0          11.267755
# 7                 0                      2.0        99.0          20.000000
#
#    worklifebalance
# 0         3.000000
# 1         3.000000
# 2         2.760507
# 5         3.000000
# 7         3.000000

# %%
sns.barplot(x ="jobsatisfaction", y = "attrition_number", data = definitivo, palette = "pastel")
# Out:
# <AxesSubplot:xlabel='jobsatisfaction', ylabel='attrition_number'>

# %%
definitivo.groupby("jobsatisfaction")["attrition_number"].mean()
# Out:
# jobsatisfaction
# 1    0.231481
# 2    0.165829
# 3    0.167192
# 4    0.117816
# Name: attrition_number, dtype: float64

# %%
# sns.regplot(x ="jobsatisfaction", y = "attrition_number", data = definitivo)
# # Establecer límites en el eje y para acortar el rango de valores
# plt.ylim(0, 0.3)
# plt.title("Relación entre satisfacción laboral y abandono para ambos grupos");

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(25, 8),sharey=True)

sns.regplot(x ="jobsatisfaction", y = "attrition_number", data = df_control, ax=axes[0])
plt.ylim(0, 0.3)
axes[0].set_title("Relación entre satisfacción laboral y abandono para grupo control (satisfacción alta)");

sns.regplot(x ="jobsatisfaction", y = "attrition_number", data = df_variante, ax=axes[1])
axes[1].set_title("Relación entre satisfacción laboral y abandono para grupo variante (satisfacción baja)");

# %% [markdown]
# # Puesto que hemos añadido la columna de "group" para crear gráfico más claro, vuelvo a guardar el df con esta columna en el excel "definitivo"

# %%
definitivo = pd.read_csv("definitivo.csv", index_col = 0)

# %%
definitivo.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'education_cat', 'educationfield',
#        'employeenumber', 'environmentsatisfaction_cat', 'gender', 'gender_cat',
#        'jobinvolvement', 'jobinvolvement_cat', 'joblevel', 'jobrole',
#        'jobsatisfaction', 'maritalstatus', 'monthlyrate', 'numcompaniesworked',
#        'overtime', 'percentsalaryhike', 'relationshipsatisfaction',
#        'relationshipsatisfaction_cat', 'stockoptionlevel',
#        'trainingtimeslastyear', 'worklifebalance_cat', 'yearsatcompany',
#        'yearssincelastpromotion', 'yearswithcurrmanager', 'remotework',
#        'attrition_number', 'environmentsatisfaction', 'hourlyrate',
#        'totalworkingyears', 'worklifebalance'],
#       dtype='object')

# %% [markdown]
# # FASE 5. CREACIÓN DE UNA ETL

# %% [markdown]
# # FASE 6. REPORTE DE RESULTADOS

# %% [markdown]
# ## 7. Análisis de registros para el mismo empleado (con el mismo employee number)

# %%
definitivo["employeenumber"].duplicated().sum()
# Out:
# 0

# %%
duplicados = definitivo[definitivo["employeenumber"].duplicated(keep=False)].sort_values("employeenumber", ascending=False)

# %%
#Sacamos los duplicados de un empleado determinado
duplicados[duplicados["employeenumber"] == 1947.0]
# Out:
# Empty DataFrame
# Columns: [age, attrition, businesstravel, dailyrate, department, distancefromhome, education, education_cat, educationfield, employeenumber, environmentsatisfaction_cat, gender, gender_cat, jobinvolvement, jobinvolvement_cat, joblevel, jobrole, jobsatisfaction, maritalstatus, monthlyrate, numcompaniesworked, overtime, percentsalaryhike, relationshipsatisfaction, relationshipsatisfaction_cat, stockoptionlevel, trainingtimeslastyear, worklifebalance_cat, yearsatcompany, yearssincelastpromotion, yearswithcurrmanager, remotework, attrition_number, environmentsatisfaction, hourlyrate, totalworkingyears, worklifebalance]
# Index: []

# %%
#Aquí estamos sacando los valores de arriba q son 2 listas, una para cada registro
duplicados[duplicados["employeenumber"] == 1947.0].values
# Out:
# array([], shape=(0, 37), dtype=object)

# %%
#valores del primero
# print(duplicados[duplicados["employeenumber"] == 1947.0].values[0])

# #valores del segundo
# print(duplicados[duplicados["employeenumber"] == 1947.0].values[1])

# %%
#Hacemos un zip de los valores de ambos registros para el mismo empleado (en este ejemploo para el empleado con employeenumber = 1947)
resultado_zip_ej = list(zip(definitivo.columns, duplicados[duplicados["employeenumber"] == 1947.0].values[0], duplicados[duplicados["employeenumber"] == 1947.0].values[1]))
resultado_zip_ej[:4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_11385/3564204961.py in <module>
#       1 #Hacemos un zip de los valores de ambos registros para el mismo empleado (en este ejemploo para el empleado con employeenumber = 1947)
# ----> 2 resultado_zip_ej = list(zip(definitivo.columns, duplicados[duplicados["employeenumber"] == 1947.0].values[0], duplicados[duplicados["employeenumber"] == 1947.0].values[1]))
#       3 resultado_zip_ej[:4]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
len(resultado_zip_ej) #Esto son todas las columnas

# %%
#Obtenemos la lista del employeenumber de aquellos empleados repetidos
lista_emplo_num = duplicados["employeenumber"].unique()
lista_emplo_num[:3]

# %%
#Creamos el zip para cada uno de los employeenumbers en nuestra "lista_emplo_num" 
dicc_cambia = {"empleado": [], "col_cambia":[]}

for empleado in lista_emplo_num[:-1]: #itermos por cada uno de los códigos en nuestra lista excepto por el último que es "nan"
    resultado_zip = list(zip(definitivo.columns, duplicados[duplicados["employeenumber"] == empleado].values[0], duplicados[duplicados["employeenumber"] == empleado].values[1]))
    
    for tupla in resultado_zip:
        if tupla[1] != tupla[2]:
            print(empleado)
            dicc_cambia["empleado"].append(empleado)
            print(tupla[0])
            dicc_cambia["col_cambia"].append(tupla[0])
            print("....")

# %%
df_resumen = pd.DataFrame(dicc_cambia)
df_resumen.sort_values("empleado")

# %%
empleados_2mascambios = df_resumen[df_resumen["empleado"].duplicated(keep=False)].sort_values("empleado", ascending=True)
len(empleados_2mascambios)

# %%
len(empleados_2mascambios["empleado"].unique()) #tenemos 27 empleados cuyas condiciones han cambiado +2

# %%
len(df_resumen["empleado"].unique()) #Para 72 empleados ha cambiado alguna de las variables medidas

# %%
df_resumen["col_cambia"].unique()

# %%
df_resumen["col_cambia"].value_counts()

# %%
df_resumen[df_resumen["col_cambia"]=="remotework"]

# %%
len(resultado_zip)

# %% [markdown]
# # 8. Recomendaciones

# %% [markdown]
# - Añadir info sobre el número de hijos, respetando la privacidad del empleado
# - Añadir información completa sobre "monthly income" - solamente disponíamos del 48% de los datos
# - Incluir la fecha de la obtención de los datos (cuando se hace la encuesta) - Algunos empleados aparecen 2 veces (no sabemos cuál es el último insertado)

# %% [markdown]
# # 9. Next steps
# 1. Hacer un análisis sobre el cambio en la situación sobre el abandono y cambios en la satisfacción de los empleados deacuerdo al cambio en sus circunstancias. Hemos observado que en la base de datos original, había registros para el mismo empleado cuya situación ha cambiado -  Análisis sobre qué factores afectan más en la satisfacción y la rotación de los empleados de acuerdo a este grupo
